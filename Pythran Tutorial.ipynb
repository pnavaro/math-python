# %% [markdown]
# ## Prelude
#
# Pythran is a compiler that turns numerical kernels into native modules.
#
# You can download it on:
#
# - PyPI: ``pip install pythran``
# - Conda: ``conda install pythran``
#
# Linux, OSX and Windows (through WinPython) are supported.
#
# Partial Python3 support.

# %% [markdown]
# # Introduction with Pi computation
#
# Computing $\pi$ is quite old fashined, but it's a good start to learn Pythran!
#
# Here is a Fortran-like version:

# %%
def pi_approximate(n):
    step = 1.0 / n
    result = 0   
    for i in range(n):
        x = (i + 0.5) * step
        result += 4.0 / (1.0 + x * x)
    return step * result

pi_approximate(1000000)
# Out:
# 3.1415926535897643

# %% [markdown]
# We can get a first glimpse of its performance using the ``timeit`` module:

# %%
# %timeit pi_approximate(1000000)
# Out:
# 170 ms ± 189 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# Turning this code into Pythran code is relatively easy. First we need to import Pythran:

# %%
import pythran
# Out:
# WARNING  Pythran support disabled for module: omp

# %% [markdown]
# And load it's notebook integration mode:

# %%
# %load_ext pythran.magic
# %env CC='gcc-7'
# %env CXX='g++-7'
# Out:
# env: CC='gcc-7'
# env: CXX='g++-7'

# %% [markdown]
# Now we'll just reproduce the code above, with an additionnal line to tell pythran about the argument type. the return type is infered.

# %%
# %%pythran
# #pythran export pi_approximate_pythran(int)
# import numpy as np
# def pi_approximate_pythran(n):
#     step = 1.0 / n
#     result = 0
#     for i in range(n):
#         x = (i + 0.5) * step
#         result += 4.0 / (1.0 + x * x)
#     return step * result
# Out:
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/range.hpp:6:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp29c5cmth.cpp:15:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:102:39: warning: 'pythonic::__builtin__::xrange::reverse_iterator pythonic::__builtin__::xrange::rend() const' defined but not used [-Wunused-function]
#      typename xrange::reverse_iterator xrange::rend() const
#                                        ^~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:97:39: warning: 'pythonic::__builtin__::xrange::reverse_iterator pythonic::__builtin__::xrange::rbegin() const' defined but not used [-Wunused-function]
#      typename xrange::reverse_iterator xrange::rbegin() const
#                                        ^~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:68:10: warning: 'bool pythonic::__builtin__::{anonymous}::xrange_iterator::operator<(const pythonic::__builtin__::{anonymous}::xrange_iterator&) const' defined but not used [-Wunused-function]
#      bool xrange_iterator::operator<(xrange_iterator const &other) const
#           ^~~~~~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:63:10: warning: 'bool pythonic::__builtin__::{anonymous}::xrange_iterator::operator==(const pythonic::__builtin__::{anonymous}::xrange_iterator&) const' defined but not used [-Wunused-function]
#      bool xrange_iterator::operator==(xrange_iterator const &other) const
#           ^~~~~~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:58:10: warning: 'bool pythonic::__builtin__::{anonymous}::xrange_iterator::operator!=(const pythonic::__builtin__::{anonymous}::xrange_iterator&) const' defined but not used [-Wunused-function]
#      bool xrange_iterator::operator!=(xrange_iterator const &other) const
#           ^~~~~~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:52:22: warning: 'pythonic::__builtin__::{anonymous}::xrange_iterator& pythonic::__builtin__::{anonymous}::xrange_iterator::operator+=(long int)' defined but not used [-Wunused-function]
#      xrange_iterator &xrange_iterator::operator+=(long n)
#                       ^~~~~~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:45:21: warning: 'pythonic::__builtin__::{anonymous}::xrange_iterator pythonic::__builtin__::{anonymous}::xrange_iterator::operator++(int)' defined but not used [-Wunused-function]
#      xrange_iterator xrange_iterator::operator++(int)
#                      ^~~~~~~~~~~~~~~

# %% [markdown]
# Hopefully, the code behaves the same:

# %%
pi_approximate_pythran(1000000)
# Out:
# 3.1415926535897643

# %% [markdown]
# But it runs faster!

# %%
# %timeit pi_approximate_pythran(1000000)
# Out:
# 3.63 ms ± 11.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Can we go faster? The astute reader has already noticed that the loop can run in parallel, so let's use OpenMP integration:

# %%
# %%pythran -fopenmp
# #pythran export pi_approximate_pythran_omp(int)
# import numpy as np
# def pi_approximate_pythran_omp(n):
#     step = 1.0 / n
#     result = 0
#     #omp parallel for reduction(+:result)
#     for i in range(n):
#         x = (i + 0.5) * step
#         result += 4.0 / (1.0 + x * x)
#     return step * result
# Out:
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/range.hpp:6:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpozqajthp.cpp:15:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:102:39: warning: 'pythonic::__builtin__::xrange::reverse_iterator pythonic::__builtin__::xrange::rend() const' defined but not used [-Wunused-function]
#      typename xrange::reverse_iterator xrange::rend() const
#                                        ^~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:97:39: warning: 'pythonic::__builtin__::xrange::reverse_iterator pythonic::__builtin__::xrange::rbegin() const' defined but not used [-Wunused-function]
#      typename xrange::reverse_iterator xrange::rbegin() const
#                                        ^~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:68:10: warning: 'bool pythonic::__builtin__::{anonymous}::xrange_iterator::operator<(const pythonic::__builtin__::{anonymous}::xrange_iterator&) const' defined but not used [-Wunused-function]
#      bool xrange_iterator::operator<(xrange_iterator const &other) const
#           ^~~~~~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:63:10: warning: 'bool pythonic::__builtin__::{anonymous}::xrange_iterator::operator==(const pythonic::__builtin__::{anonymous}::xrange_iterator&) const' defined but not used [-Wunused-function]
#      bool xrange_iterator::operator==(xrange_iterator const &other) const
#           ^~~~~~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:58:10: warning: 'bool pythonic::__builtin__::{anonymous}::xrange_iterator::operator!=(const pythonic::__builtin__::{anonymous}::xrange_iterator&) const' defined but not used [-Wunused-function]
#      bool xrange_iterator::operator!=(xrange_iterator const &other) const
#           ^~~~~~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:52:22: warning: 'pythonic::__builtin__::{anonymous}::xrange_iterator& pythonic::__builtin__::{anonymous}::xrange_iterator::operator+=(long int)' defined but not used [-Wunused-function]
#      xrange_iterator &xrange_iterator::operator+=(long n)
#                       ^~~~~~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/__builtin__/xrange.hpp:45:21: warning: 'pythonic::__builtin__::{anonymous}::xrange_iterator pythonic::__builtin__::{anonymous}::xrange_iterator::operator++(int)' defined but not used [-Wunused-function]
#      xrange_iterator xrange_iterator::operator++(int)
#                      ^~~~~~~~~~~~~~~

# %%
# %timeit pi_approximate_pythran_omp(1000000)
# Out:
# 1e+03 µs ± 27.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# But everything looks very Fortran-ish in this example. Why not trying the following:

# %%
import numpy as np
def pi_numpy_style(n):
    step = 1.0 / n
    x = (np.arange(0, n, dtype=np.float64) + 0.5) * step
    return step * np.sum(4. / (1. + x ** 2))

# %% [markdown]
# It works the same, but it's already faster as most of the computations are done using native code:

# %%
pi_numpy_style(1000000)
# Out:
# 3.1415926535898775

# %%
# %timeit pi_numpy_style(1000000)
# Out:
# 8.86 ms ± 34.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Good new! Pythran can also handle this version, without much changes:

# %%
# %%pythran
# #pythran export pi_numpy_style_pythran(int)
# import numpy as np
# def pi_numpy_style_pythran(n):
#     step = 1.0 / n
#     x = (np.arange(0, n, dtype=np.float64) + 0.5) * step
#     return step * np.sum(4. / (1. + x ** 2))
# Out:
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/div.hpp:7:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:16:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp: In function 'bool pythonic::operator_::lshift(bool, bool)':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp:21:48: warning: '<<' in boolean context, did you mean '<' ? [-Wint-in-bool-context]
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(lshift, << )
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/overloads.hpp:9:14: note: in definition of macro 'PYTHONIC_OPERATOR_OVERLOAD_IMPL'
#      return a op b;                                                             \
#               ^~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp:21:5: note: in expansion of macro 'DEFINE_ALL_OPERATOR_OVERLOADS_IMPL'
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(lshift, << )
#      ^
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp: In function 'bool pythonic::operator_::mul(bool, bool)':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp:21:45: warning: '*' in boolean context, suggest '&&' instead [-Wint-in-bool-context]
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(mul, *)
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/overloads.hpp:9:14: note: in definition of macro 'PYTHONIC_OPERATOR_OVERLOAD_IMPL'
#      return a op b;                                                             \
#               ^~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp:21:5: note: in expansion of macro 'DEFINE_ALL_OPERATOR_OVERLOADS_IMPL'
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(mul, *)
#      ^
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:38:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:6,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:5,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:18:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::add; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::add, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator+(const E0&, const E1&) [with E0 = pythonic::types::ndarray<double, 1>; E1 = double; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::add, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:54:210:   required from 'typename __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::type<argument_type0>::result_type __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:64:126:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < value; ++i) {
#                          ~~^~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::mul; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator*(const E0&, const E1&) [with E0 = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >; E1 = double; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:54:217:   required from 'typename __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::type<argument_type0>::result_type __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:64:126:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::numpy::functor::square; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_nary_expr.hpp:39:20:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type pythonic::numpy::functor::square::operator()(const E& ...) const [with E = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >}; typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:54:124:   required from 'typename __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::type<argument_type0>::result_type __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:64:126:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::add; Args = {pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::add, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator+(const E0&, const E1&) [with E0 = double; E1 = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::add, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:54:88:   required from 'typename __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::type<argument_type0>::result_type __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:64:126:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::div; Args = {pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::div, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator/(const E0&, const E1&) [with E0 = double; E1 = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::div, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/div.hpp:22:16:   required from 'typename std::enable_if<((! std::is_fundamental<_Tp>::value) || (! std::is_fundamental<B>::value)), decltype ((a / b))>::type pythonic::operator_::div(const A&, const B&) [with A = double; B = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >; typename std::enable_if<((! std::is_fundamental<_Tp>::value) || (! std::is_fundamental<B>::value)), decltype ((a / b))>::type = pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:54:77:   required from 'typename __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::type<argument_type0>::result_type __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:64:126:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/ndarray.hpp:17:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/numpy/reduce.hpp:4,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/numpy/sum.hpp:4,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:13:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp: In instantiation of 'pythonic::types::raw_array<T>::raw_array(size_t) [with T = double; size_t = long unsigned int]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:26:71:   required from 'pythonic::utils::shared_ref<T>::memory::memory(Types&& ...) [with Types = {int}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:43:15:   required from 'pythonic::utils::shared_ref<T>::shared_ref(Types&& ...) [with Types = {int}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:306:73:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::array<long int, M>&, pythonic::types::none_type) [with T = double; long unsigned int N = 1]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/arange.hpp:20:28:   required from 'pythonic::types::ndarray<typename dtype::type, 1> pythonic::numpy::arange(T, U, S, dtype) [with T = long int; U = long int; S = long int; dtype = pythonic::numpy::functor::float64; typename dtype::type = double]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/arange.hpp:38:5:   required from 'decltype (pythonic::numpy::arange((forward<Types>)(pythonic::numpy::functor::arange::operator()::types)...)) pythonic::numpy::functor::arange::operator()(Types&& ...) const [with Types = {long int, const long int&, long int, pythonic::numpy::functor::float64}; decltype (pythonic::numpy::arange((forward<Types>)(pythonic::numpy::functor::arange::operator()::types)...)) = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:54:161:   required from 'typename __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::type<argument_type0>::result_type __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_36b1dd7c830b8007a5346e21be4ec31a::pi_numpy_style_pythran::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:64:126:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:26:10: warning: 'pythonic::types::raw_array<double>::data' will be initialized after [-Wreorder]
#        T *data;
#           ^~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:21:12: warning:   'bool pythonic::types::raw_array<double>::external' [-Wreorder]
#        bool external;
#             ^~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:19:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:6,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:5,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpeer_k62w.cpp:18:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp:22:5: warning:   when initialized here [-Wreorder]
#      raw_array<T>::raw_array(size_t n)
#      ^~~~~~~~~~~~

# %% [markdown]
# It still works, and runs almost as fast as the numpy-free version converted by Pythran:

# %%
pi_numpy_style_pythran(1000000)
# Out:
# 3.1415926535897643

# %%
# %timeit pi_numpy_style_pythran(1000000)
# Out:
# 5.68 ms ± 20.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Cherry on the cake: Pythran can take advantage of the vectorized code to generate SIMD code:

# %%
# %%pythran -DUSE_BOOST_SIMD -march=native
# #pythran export pi_numpy_style_pythran_simd(int)
# import numpy as np
# def pi_numpy_style_pythran_simd(n):
#     step = 1.0 / n
#     x = (np.arange(0, n, dtype=np.float64) + 0.5) * step
#     return step * np.sum(4. / (1. + x ** 2))
# Out:
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/div.hpp:7:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:16:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp: In function 'bool pythonic::operator_::lshift(bool, bool)':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp:21:48: warning: '<<' in boolean context, did you mean '<' ? [-Wint-in-bool-context]
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(lshift, << )
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/overloads.hpp:9:14: note: in definition of macro 'PYTHONIC_OPERATOR_OVERLOAD_IMPL'
#      return a op b;                                                             \
#               ^~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp:21:5: note: in expansion of macro 'DEFINE_ALL_OPERATOR_OVERLOADS_IMPL'
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(lshift, << )
#      ^
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp: In function 'bool pythonic::operator_::mul(bool, bool)':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp:21:45: warning: '*' in boolean context, suggest '&&' instead [-Wint-in-bool-context]
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(mul, *)
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/overloads.hpp:9:14: note: in definition of macro 'PYTHONIC_OPERATOR_OVERLOAD_IMPL'
#      return a op b;                                                             \
#               ^~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp:21:5: note: in expansion of macro 'DEFINE_ALL_OPERATOR_OVERLOADS_IMPL'
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(mul, *)
#      ^
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:38:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:6,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:5,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:18:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::add; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::add, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator+(const E0&, const E1&) [with E0 = pythonic::types::ndarray<double, 1>; E1 = double; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::add, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:54:210:   required from 'typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:64:131:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < value; ++i) {
#                          ~~^~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::mul; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator*(const E0&, const E1&) [with E0 = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >; E1 = double; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:54:217:   required from 'typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:64:131:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::numpy::functor::square; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_nary_expr.hpp:39:20:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type pythonic::numpy::functor::square::operator()(const E& ...) const [with E = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >}; typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:54:124:   required from 'typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:64:131:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::add; Args = {pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::add, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator+(const E0&, const E1&) [with E0 = double; E1 = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::add, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:54:88:   required from 'typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:64:131:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::div; Args = {pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::div, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator/(const E0&, const E1&) [with E0 = double; E1 = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::div, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/div.hpp:22:16:   required from 'typename std::enable_if<((! std::is_fundamental<_Tp>::value) || (! std::is_fundamental<B>::value)), decltype ((a / b))>::type pythonic::operator_::div(const A&, const B&) [with A = double; B = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >; typename std::enable_if<((! std::is_fundamental<_Tp>::value) || (! std::is_fundamental<B>::value)), decltype ((a / b))>::type = pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:54:77:   required from 'typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:64:131:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/ndarray.hpp:17:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/numpy/reduce.hpp:4,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/numpy/sum.hpp:4,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:13:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp: In instantiation of 'pythonic::types::raw_array<T>::raw_array(size_t) [with T = double; size_t = long unsigned int]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:26:71:   required from 'pythonic::utils::shared_ref<T>::memory::memory(Types&& ...) [with Types = {int}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:43:15:   required from 'pythonic::utils::shared_ref<T>::shared_ref(Types&& ...) [with Types = {int}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:306:73:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::array<long int, M>&, pythonic::types::none_type) [with T = double; long unsigned int N = 1]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/arange.hpp:20:28:   required from 'pythonic::types::ndarray<typename dtype::type, 1> pythonic::numpy::arange(T, U, S, dtype) [with T = long int; U = long int; S = long int; dtype = pythonic::numpy::functor::float64; typename dtype::type = double]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/arange.hpp:38:5:   required from 'decltype (pythonic::numpy::arange((forward<Types>)(pythonic::numpy::functor::arange::operator()::types)...)) pythonic::numpy::functor::arange::operator()(Types&& ...) const [with Types = {long int, const long int&, long int, pythonic::numpy::functor::float64}; decltype (pythonic::numpy::arange((forward<Types>)(pythonic::numpy::functor::arange::operator()::types)...)) = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:54:161:   required from 'typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:64:131:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:26:10: warning: 'pythonic::types::raw_array<double>::data' will be initialized after [-Wreorder]
#        T *data;
#           ^~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:21:12: warning:   'bool pythonic::types::raw_array<double>::external' [-Wreorder]
#        bool external;
#             ^~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:19:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:6,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:5,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:18:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp:22:5: warning:   when initialized here [-Wreorder]
#      raw_array<T>::raw_array(size_t n)
#      ^~~~~~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/ndarray.hpp:36:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/numpy/reduce.hpp:4,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/numpy/sum.hpp:4,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:13:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp: In instantiation of 'pythonic::types::numpy_expr_simd_iterator<E, Op, SIters, Iters>::numpy_expr_simd_iterator(const pythonic::types::numpy_expr_simd_iterator<E, Op, SIters, Iters>&) [with E = pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >; Op = pythonic::operator_::functor::div; SIters = std::tuple<pythonic::types::const_broadcast_iterator<double>, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, pythonic::types::const_broadcast_iterator<double>, pythonic::types::numpy_expr_iterator<pythonic::numpy::functor::square, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> > > > >; Iters = {pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >, pythonic::operator_::functor::add, std::tuple<pythonic::types::const_broadcast_iterator<double>, pythonic::types::numpy_expr_iterator<pythonic::numpy::functor::square, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> > > >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >, pythonic::numpy::functor::square, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> > >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::add, std::tuple<const double*, pythonic::types::const_b ...
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:48:12:   required from 'F pythonic::numpy::vreduce(E, F) [with vectorizer = pythonic::types::vectorizer; Op = pythonic::operator_::functor::iadd; E = pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >; F = double]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:73:46:   required from 'F pythonic::numpy::_reduce<Op, 1, pythonic::types::vectorizer>::operator()(E, F) [with E = pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >; F = double; Op = pythonic::operator_::functor::iadd]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:105:60:   required from 'pythonic::numpy::{anonymous}::reduce_result_type<E> pythonic::numpy::reduce_helper<Op, E, true>::operator()(const E&, pythonic::numpy::{anonymous}::reduce_result_type<E>) const [with Op = pythonic::operator_::functor::iadd; E = pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >; pythonic::numpy::{anonymous}::reduce_result_type<E> = double]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:118:53:   required from 'typename std::enable_if<pythonic::types::is_numexpr_arg<E>::value, typename std::conditional<std::is_same<typename E::dtype, bool>::value, long int, typename E::dtype>::type>::type pythonic::numpy::reduce(const E&, pythonic::types::none_type) [with Op = pythonic::operator_::functor::iadd; E = pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >; typename std::enable_if<pythonic::types::is_numexpr_arg<E>::value, typename std::conditional<std::is_same<typename E::dtype, bool>::value, long int, typename E::dtype>::type>::type = double]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:21:46:   required from 'decltype (reduce<pythonic::operator_::functor::iadd>((forward<Args>)(pythonic::numpy::sum::args)...)) pythonic::numpy::sum(Args&& ...) [with Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >}; decltype (reduce<pythonic::operator_::functor::iadd>((forward<Args>)(pythonic::numpy::sum::args)...)) = double]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:24:5:   required from 'decltype (pythonic::numpy::sum((forward<Types>)(pythonic::numpy::functor::sum::operator()::types)...)) pythonic::numpy::functor::sum::operator()(Types&& ...) const [with Types = {pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >}; decltype (pythonic::numpy::sum((forward<Types>)(pythonic::numpy::functor::sum::operator()::types)...)) = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:54:51:   required from 'typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:64:131:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:176:14: warning: 'pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >, pythonic::operator_::functor::div, std::tuple<pythonic::types::const_broadcast_iterator<double>, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, pythonic::types::const_broadcast_iterator<double>, pythonic::types::numpy_expr_iterator<pythonic::numpy::functor::square, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> > > > >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >, pythonic::operator_::functor::add, std::tuple<pythonic::types::const_broadcast_iterator<double>, pythonic::types::numpy_expr_iterator<pythonic::numpy::functor::square, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> > > >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >, pythonic::numpy::functor::square, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> > >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::add, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::s ...
#        SIters siters_;
#               ^~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:175:28: warning:   'std::tuple<pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >, pythonic::operator_::functor::add, std::tuple<pythonic::types::const_broadcast_iterator<double>, pythonic::types::numpy_expr_iterator<pythonic::numpy::functor::square, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> > > >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >, pythonic::numpy::functor::square, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> > >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::add, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > > > > > pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >, pythonic::operator_::functor::div, std::tuple<pythonic::types::const_broadcast_iterator<double>, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, pythonic::types::const_broadcast_iterator<double>, pythonic::types::numpy_expr_iterator<pythonic::numpy::functor::square, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pyth ...
#        std::tuple<Iters...> iters_;
#                             ^~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:184:7: warning:   when initialized here [-Wreorder]
#        numpy_expr_simd_iterator(numpy_expr_simd_iterator const &other)
#        ^~~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp: In instantiation of 'pythonic::types::numpy_expr_simd_iterator<E, Op, SIters, Iters>::numpy_expr_simd_iterator(const pythonic::types::numpy_expr_simd_iterator<E, Op, SIters, Iters>&) [with E = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >; Op = pythonic::operator_::functor::add; SIters = std::tuple<pythonic::types::const_broadcast_iterator<double>, pythonic::types::numpy_expr_iterator<pythonic::numpy::functor::square, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> > > >; Iters = {pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >, pythonic::numpy::functor::square, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> > >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::add, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > > >}]':
# ...
#        std::tuple<Iters...> iters_;
#                             ^~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:178:7: warning:   when initialized here [-Wreorder]
#        numpy_expr_simd_iterator(std::array<long, sizeof...(Iters)> steps,
#        ^~~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp: In instantiation of 'pythonic::types::numpy_expr_simd_iterator<E, Op, SIters, Iters>::numpy_expr_simd_iterator(std::array<long int, sizeof... (Iters)>, const SIters&, Iters ...) [with E = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >; Op = pythonic::operator_::functor::add; SIters = std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >; Iters = {pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:208:55:   required from 'pythonic::types::numpy_expr<Op, Args>::simd_iterator pythonic::types::numpy_expr<Op, Args>::_vbegin(pythonic::types::vectorize, pythonic::utils::index_sequence<S ...>) const [with long unsigned int ...I = {0, 1}; Op = pythonic::operator_::functor::add; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double>}; pythonic::types::numpy_expr<Op, Args>::simd_iterator = pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::add, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >; pythonic::utils::index_sequence<S ...> = pythonic::utils::integer_sequence<long unsigned int, 0, 1>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:215:21:   required from 'pythonic::types::numpy_expr<Op, Args>::simd_iterator pythonic::types::numpy_expr<Op, Args>::vbegin(pythonic::types::vectorize) const [with Op = pythonic::operator_::functor::add; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double>}; pythonic::types::numpy_expr<Op, Args>::simd_iterator = pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::add, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:208:55:   required from 'pythonic::types::numpy_expr<Op, Args>::simd_iterator pythonic::types::numpy_expr<Op, Args>::_vbegin(pythonic::types::vectorize, pythonic::utils::index_sequence<S ...>) const [with long unsigned int ...I = {0, 1}; Op = pythonic::operator_::functor::mul; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double>}; pythonic::types::numpy_expr<Op, Args>::simd_iterator = pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::add, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >; pythonic::utils::index_sequence<S ...> = pythonic::utils::integer_sequence<long unsigned int, 0, 1>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:215:21:   required from 'pythonic::types::numpy_expr<Op, Args>::simd_iterator pythonic::types::numpy_expr<Op, Args>::vbegin(pythonic::types::vectorize) const [with Op = pythonic::operator_::functor::mul; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double>}; pythonic::types::numpy_expr<Op, Args>::simd_iterator = pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::add, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:208:55:   required from 'pythonic::types::numpy_expr<Op, Args>::simd_iterator pythonic::types::numpy_expr<Op, Args>::_vbegin(pythonic::types::vectorize, pythonic::utils::index_sequence<S ...>) const [with long unsigned int ...I = {0}; Op = pythonic::numpy::functor::square; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >}; pythonic::types::numpy_expr<Op, Args>::simd_iterator = pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >, pythonic::numpy::functor::square, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> > >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::add, const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::add, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > > >; pythonic::utils::index_sequence<S ...> = pythonic::utils::integer_sequence<long unsigned int, 0>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:215:21:   [ skipping 8 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:105:60:   required from 'pythonic::numpy::{anonymous}::reduce_result_type<E> pythonic::numpy::reduce_helper<Op, E, true>::operator()(const E&, pythonic::numpy::{anonymous}::reduce_result_type<E>) const [with Op = pythonic::operator_::functor::iadd; E = pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >; pythonic::numpy::{anonymous}::reduce_result_type<E> = double]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:118:53:   required from 'typename std::enable_if<pythonic::types::is_numexpr_arg<E>::value, typename std::conditional<std::is_same<typename E::dtype, bool>::value, long int, typename E::dtype>::type>::type pythonic::numpy::reduce(const E&, pythonic::types::none_type) [with Op = pythonic::operator_::functor::iadd; E = pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >; typename std::enable_if<pythonic::types::is_numexpr_arg<E>::value, typename std::conditional<std::is_same<typename E::dtype, bool>::value, long int, typename E::dtype>::type>::type = double]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:21:46:   required from 'decltype (reduce<pythonic::operator_::functor::iadd>((forward<Args>)(pythonic::numpy::sum::args)...)) pythonic::numpy::sum(Args&& ...) [with Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >}; decltype (reduce<pythonic::operator_::functor::iadd>((forward<Args>)(pythonic::numpy::sum::args)...)) = double]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:24:5:   required from 'decltype (pythonic::numpy::sum((forward<Types>)(pythonic::numpy::functor::sum::operator()::types)...)) pythonic::numpy::functor::sum::operator()(Types&& ...) const [with Types = {pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >}; decltype (pythonic::numpy::sum((forward<Types>)(pythonic::numpy::functor::sum::operator()::types)...)) = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:54:51:   required from 'typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_8ab07708f01b6abec9fd6ffd27ed04cf::pi_numpy_style_pythran_simd::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpivl7gyzy.cpp:64:131:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:176:14: warning: 'pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::add, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >::siters_' will be initialized after [-Wreorder]
#        SIters siters_;
#               ^~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:175:28: warning:   'std::tuple<pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > > pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::add, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >::iters_' [-Wreorder]
#        std::tuple<Iters...> iters_;
#                             ^~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:178:7: warning:   when initialized here [-Wreorder]
#        numpy_expr_simd_iterator(std::array<long, sizeof...(Iters)> steps,
#        ^~~~~~~~~~~~~~~~~~~~~~~~

# %%
# %timeit pi_numpy_style_pythran_simd(1000000)
# Out:
# 3.94 ms ± 84.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## Pythran in a nutshell
#
# - DSL embeded into Python (no technological debt)
# - Minimalists type annotations (only the exported functions)
# - Parallelization and Vectorization are possible
# - Supports (an already large part of) Numpy and Python builtins

# %% [markdown]
# # Type Annotations
#
# Consider the following function:

# %%
def pairwise_distance(X):
    return np.sqrt(((X[:, None, :] - X) ** 2).sum(-1))

# %% [markdown]
# It makes use of fancy indexing, broadcasting and Numpy. And it's polymorphic!

# %%
size = 100
args32 = np.random.random((size, size)).astype(np.float32)
args64 = np.random.random((size, size)).astype(np.float64)  #cast useless
# %timeit pairwise_distance(args32)
# %timeit pairwise_distance(args64)
# Out:
# 1.2 ms ± 2.77 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.3 ms ± 18.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Pythran can handle all of this! Note the double export to specify the overloads:

# %%
# %%pythran
# import numpy as np
# #pythran export pairwise_distance_pythran(float32[][])
# #pythran export pairwise_distance_pythran(float64[:,:])
# def pairwise_distance_pythran(X):
#     print (X.dtype)
#     return np.sqrt(((X[:, None, :] - X) ** 2).sum(-1))
# Out:
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/add.hpp:7:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_operators.hpp:7,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:1132,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:14:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp: In function 'bool pythonic::operator_::lshift(bool, bool)':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp:21:48: warning: '<<' in boolean context, did you mean '<' ? [-Wint-in-bool-context]
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(lshift, << )
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/overloads.hpp:9:14: note: in definition of macro 'PYTHONIC_OPERATOR_OVERLOAD_IMPL'
#      return a op b;                                                             \
#               ^~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp:21:5: note: in expansion of macro 'DEFINE_ALL_OPERATOR_OVERLOADS_IMPL'
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(lshift, << )
#      ^
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp: In function 'bool pythonic::operator_::mul(bool, bool)':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp:21:45: warning: '*' in boolean context, suggest '&&' instead [-Wint-in-bool-context]
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(mul, *)
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/overloads.hpp:9:14: note: in definition of macro 'PYTHONIC_OPERATOR_OVERLOAD_IMPL'
#      return a op b;                                                             \
#               ^~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp:21:5: note: in expansion of macro 'DEFINE_ALL_OPERATOR_OVERLOADS_IMPL'
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(mul, *)
#      ^
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:38:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:14:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 3; Args = {pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<double, 2> >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::sub; Args = {pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<double, 2> >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator-(const E0&, const E1&) [with E0 = pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>; E1 = pythonic::types::ndarray<double, 2>; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<double, 2> > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:326:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::ndarray<double, 2>; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<double, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:69:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < value; ++i) {
#                          ~~^~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 3; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<double, 2> > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::numpy::functor::square; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<double, 2> > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_nary_expr.hpp:39:20:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type pythonic::numpy::functor::square::operator()(const E& ...) const [with E = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<double, 2> > >}; typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<double, 2> > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:111:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::ndarray<double, 2>; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<double, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:69:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 2; Args = {pythonic::types::ndarray<double, 2>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::numpy::functor::sqrt; Args = {pythonic::types::ndarray<double, 2>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_nary_expr.hpp:39:20:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type pythonic::numpy::functor::sqrt::operator()(const E& ...) const [with E = {pythonic::types::ndarray<double, 2>}; typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<double, 2> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:44:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::ndarray<double, 2>; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<double, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:69:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 3; Args = {pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<double, 2> > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::sub; Args = {pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<double, 2> > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator-(const E0&, const E1&) [with E0 = pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>; E1 = pythonic::types::numpy_texpr<pythonic::types::ndarray<double, 2> >; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<double, 2> > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:326:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::numpy_texpr<pythonic::types::ndarray<double, 2> >; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<double, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:84:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 3; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<double, 2> > > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::numpy::functor::square; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<double, 2> > > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_nary_expr.hpp:39:20:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type pythonic::numpy::functor::square::operator()(const E& ...) const [with E = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<double, 2> > > >}; typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<double, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<double, 2> > > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:111:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::numpy_texpr<pythonic::types::ndarray<double, 2> >; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<double, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:84:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 3; Args = {pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<float, 2> >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::sub; Args = {pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<float, 2> >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator-(const E0&, const E1&) [with E0 = pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>; E1 = pythonic::types::ndarray<float, 2>; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<float, 2> > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:326:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::ndarray<float, 2>; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<float, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:99:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 3; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<float, 2> > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::numpy::functor::square; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<float, 2> > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_nary_expr.hpp:39:20:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type pythonic::numpy::functor::square::operator()(const E& ...) const [with E = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<float, 2> > >}; typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<float, 2> > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:111:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::ndarray<float, 2>; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<float, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:99:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 2; Args = {pythonic::types::ndarray<float, 2>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::numpy::functor::sqrt; Args = {pythonic::types::ndarray<float, 2>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_nary_expr.hpp:39:20:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type pythonic::numpy::functor::sqrt::operator()(const E& ...) const [with E = {pythonic::types::ndarray<float, 2>}; typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<float, 2> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:44:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::ndarray<float, 2>; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<float, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:99:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 3; Args = {pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::sub; Args = {pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator-(const E0&, const E1&) [with E0 = pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>; E1 = pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> >; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:326:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> >; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<float, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:114:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 3; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::numpy::functor::square; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_nary_expr.hpp:39:20:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type pythonic::numpy::functor::square::operator()(const E& ...) const [with E = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > > >}; typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:111:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> >; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<float, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:114:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/ndarray.hpp:17:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_texpr.hpp:4,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:11:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp: In instantiation of 'pythonic::types::raw_array<T>::raw_array(size_t) [with T = double; size_t = long unsigned int]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:26:71:   required from 'pythonic::utils::shared_ref<T>::memory::memory(Types&& ...) [with Types = {long int}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:43:15:   required from 'pythonic::utils::shared_ref<T>::shared_ref(Types&& ...) [with Types = {long int}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:366:40:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::sqrt; Args = {pythonic::types::ndarray<double, 2>}; T = double; long unsigned int N = 2]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:337:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::ndarray<double, 2>; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<double, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:69:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:26:10: warning: 'pythonic::types::raw_array<double>::data' will be initialized after [-Wreorder]
#        T *data;
#           ^~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:21:12: warning:   'bool pythonic::types::raw_array<double>::external' [-Wreorder]
#        bool external;
#             ^~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:19:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:14:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp:22:5: warning:   when initialized here [-Wreorder]
#      raw_array<T>::raw_array(size_t n)
#      ^~~~~~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/ndarray.hpp:17:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_texpr.hpp:4,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:11:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp: In instantiation of 'pythonic::types::raw_array<T>::raw_array(size_t) [with T = float; size_t = long unsigned int]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:26:71:   required from 'pythonic::utils::shared_ref<T>::memory::memory(Types&& ...) [with Types = {long int}; T = pythonic::types::raw_array<float>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:43:15:   required from 'pythonic::utils::shared_ref<T>::shared_ref(Types&& ...) [with Types = {long int}; T = pythonic::types::raw_array<float>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:366:40:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::sqrt; Args = {pythonic::types::ndarray<float, 2>}; T = float; long unsigned int N = 2]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:337:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::ndarray<float, 2>; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<float, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:99:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:26:10: warning: 'pythonic::types::raw_array<float>::data' will be initialized after [-Wreorder]
#        T *data;
#           ^~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:21:12: warning:   'bool pythonic::types::raw_array<float>::external' [-Wreorder]
#        bool external;
#             ^~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:19:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:14:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp:22:5: warning:   when initialized here [-Wreorder]
#      raw_array<T>::raw_array(size_t n)
#      ^~~~~~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:14:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:14:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp: In instantiation of 'void pythonic::utils::_broadcast_copy<vectorizer, N, 0>::operator()(E&&, const F&) [with E = pythonic::types::ndarray<double, 2>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<double, 2> >; long unsigned int N = 2; vectorizer = pythonic::types::vectorizer_nobroadcast]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:190:65:   required from 'void pythonic::utils::broadcast_copy_dispatcher<E, F, N, D, true>::operator()(E&, const F&) [with E = pythonic::types::ndarray<double, 2>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<double, 2> >; long unsigned int N = 2; long unsigned int D = 0]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:199:59:   required from 'E& pythonic::utils::broadcast_copy(E&, const F&) [with E = pythonic::types::ndarray<double, 2>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<double, 2> >; long unsigned int N = 2; long unsigned int D = 0; bool vector_form = true]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:358:79:   required from 'void pythonic::types::ndarray<T, N>::initialize_from_expr(const E&) [with E = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<double, 2> >; T = double; long unsigned int N = 2]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:368:27:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::sqrt; Args = {pythonic::types::ndarray<double, 2>}; T = double; long unsigned int N = 2]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:337:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::ndarray<double, 2>; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<double, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:69:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:78:41: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#            for (size_t i = other_size; i < self_size; i += other_size)
#                                        ~~^~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp: In instantiation of 'void pythonic::utils::_broadcast_copy<vectorizer, N, 0>::operator()(E&&, const F&) [with E = pythonic::types::ndarray<double, 2>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<double, 2> >; long unsigned int N = 2; vectorizer = pythonic::types::vectorizer]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:192:53:   required from 'void pythonic::utils::broadcast_copy_dispatcher<E, F, N, D, true>::operator()(E&, const F&) [with E = pythonic::types::ndarray<double, 2>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<double, 2> >; long unsigned int N = 2; long unsigned int D = 0]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:199:59:   required from 'E& pythonic::utils::broadcast_copy(E&, const F&) [with E = pythonic::types::ndarray<double, 2>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<double, 2> >; long unsigned int N = 2; long unsigned int D = 0; bool vector_form = true]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:358:79:   required from 'void pythonic::types::ndarray<T, N>::initialize_from_expr(const E&) [with E = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<double, 2> >; T = double; long unsigned int N = 2]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:368:27:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::sqrt; Args = {pythonic::types::ndarray<double, 2>}; T = double; long unsigned int N = 2]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:337:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::ndarray<double, 2>; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<double, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:69:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:78:41: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp: In instantiation of 'void pythonic::utils::_broadcast_copy<vectorizer, N, 0>::operator()(E&&, const F&) [with E = pythonic::types::ndarray<float, 2>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<float, 2> >; long unsigned int N = 2; vectorizer = pythonic::types::vectorizer_nobroadcast]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:190:65:   required from 'void pythonic::utils::broadcast_copy_dispatcher<E, F, N, D, true>::operator()(E&, const F&) [with E = pythonic::types::ndarray<float, 2>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<float, 2> >; long unsigned int N = 2; long unsigned int D = 0]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:199:59:   required from 'E& pythonic::utils::broadcast_copy(E&, const F&) [with E = pythonic::types::ndarray<float, 2>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<float, 2> >; long unsigned int N = 2; long unsigned int D = 0; bool vector_form = true]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:358:79:   required from 'void pythonic::types::ndarray<T, N>::initialize_from_expr(const E&) [with E = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<float, 2> >; T = float; long unsigned int N = 2]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:368:27:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::sqrt; Args = {pythonic::types::ndarray<float, 2>}; T = float; long unsigned int N = 2]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:337:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::ndarray<float, 2>; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<float, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:99:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:78:41: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp: In instantiation of 'void pythonic::utils::_broadcast_copy<vectorizer, N, 0>::operator()(E&&, const F&) [with E = pythonic::types::ndarray<float, 2>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::sqrt, pythonic::types::ndarray<float, 2> >; long unsigned int N = 2; vectorizer = pythonic::types::vectorizer]':
# ...
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:170:23:   required from 'typename std::enable_if<(E:: value != 1), pythonic::types::ndarray<typename E::dtype, (E:: value - 1)> >::type pythonic::numpy::reduce(const E&, long int, pythonic::types::none_type, pythonic::types::none_type) [with Op = pythonic::operator_::functor::iadd; E = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<float, 2> > > >; typename std::enable_if<(E:: value != 1), pythonic::types::ndarray<typename E::dtype, (E:: value - 1)> >::type = pythonic::types::ndarray<float, 2>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:21:46:   required from 'decltype (reduce<pythonic::operator_::functor::iadd>((forward<Args>)(pythonic::numpy::sum::args)...)) pythonic::numpy::sum(Args&& ...) [with Args = {pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<float, 2> > > >, long int}; decltype (reduce<pythonic::operator_::functor::iadd>((forward<Args>)(pythonic::numpy::sum::args)...)) = pythonic::types::ndarray<float, 2>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:24:5:   required from 'decltype (pythonic::numpy::sum((forward<Types>)(pythonic::numpy::functor::sum::operator()::types)...)) pythonic::numpy::functor::sum::operator()(Types&& ...) const [with Types = {pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::ndarray<float, 2> > > >, long int}; decltype (pythonic::numpy::sum((forward<Types>)(pythonic::numpy::functor::sum::operator()::types)...)) = pythonic::types::ndarray<float, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:76:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::ndarray<float, 2>; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<float, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:99:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_gexpr<pythonic::types::numpy_iexpr<const pythonic::types::numpy_iexpr<const pythonic::types::ndarray<float, 3>&>&>, pythonic::types::contiguous_slice>, pythonic::types::numpy_gexpr<const pythonic::types::ndarray<float, 2>&, pythonic::types::contiguous_slice, long int>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::sub; Args = {pythonic::types::numpy_gexpr<pythonic::types::numpy_iexpr<const pythonic::types::numpy_iexpr<const pythonic::types::ndarray<float, 3>&>&>, pythonic::types::contiguous_slice>, pythonic::types::numpy_gexpr<const pythonic::types::ndarray<float, 2>&, pythonic::types::contiguous_slice, long int>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator-(const E0&, const E1&) [with E0 = pythonic::types::numpy_gexpr<pythonic::types::numpy_iexpr<const pythonic::types::numpy_iexpr<const pythonic::types::ndarray<float, 3>&>&>, pythonic::types::contiguous_slice>; E1 = pythonic::types::numpy_gexpr<const pythonic::types::ndarray<float, 2>&, pythonic::types::contiguous_slice, long int>; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::numpy_iexpr<const pythonic::types::numpy_iexpr<const pythonic::types::ndarray<float, 3>&>&>, pythonic::types::contiguous_slice>, pythonic::types::numpy_gexpr<const pythonic::types::ndarray<float, 2>&, pythonic::types::contiguous_slice, long int> >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/sub.hpp:18:16:   required from 'decltype ((a - b)) pythonic::operator_::sub(const A&, const B&) [with A = pythonic::types::numpy_gexpr<pythonic::types::numpy_iexpr<const pythonic::types::numpy_iexpr<const pythonic::types::ndarray<float, 3>&>&>, pythonic::types::contiguous_slice>; B = pythonic::types::numpy_gexpr<const pythonic::types::ndarray<float, 2>&, pythonic::types::contiguous_slice, long int>; decltype ((a - b)) = pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::numpy_iexpr<const pythonic::types::numpy_iexpr<const pythonic::types::ndarray<float, 3>&>&>, pythonic::types::contiguous_slice>, pythonic::types::numpy_gexpr<const pythonic::types::ndarray<float, 2>&, pythonic::types::contiguous_slice, long int> >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/sub.hpp:23:5:   required from 'decltype (pythonic::operator_::sub((forward<Types>)(pythonic::operator_::functor::sub::operator()::types)...)) pythonic::operator_::functor::sub::operator()(Types&& ...) const [with Types = {pythonic::types::numpy_gexpr<pythonic::types::numpy_iexpr<const pythonic::types::numpy_iexpr<const pythonic::types::ndarray<float, 3>&>&>, pythonic::types::contiguous_slice>, pythonic::types::numpy_gexpr<const pythonic::types::ndarray<float, 2>&, pythonic::types::contiguous_slice, long int>}; decltype (pythonic::operator_::sub((forward<Types>)(pythonic::operator_::functor::sub::operator()::types)...)) = pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::numpy_iexpr<const pythonic::types::numpy_iexpr<const pythonic::types::ndarray<float, 3>&>&>, pythonic::types::contiguous_slice>, pythonic::types::numpy_gexpr<const pythonic::types::ndarray<float, 2>&, pythonic::types::contiguous_slice, long int> >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:25:20:   required from 'decltype (Op{}(*(get<I>)(pythonic::types::Dereferencer::operator()::iters)...)) pythonic::types::Dereferencer<Op>::operator()(const Ts&, pythonic::utils::index_sequence<I ...>) [with Ts = std::tuple<pythonic::types::nditerator<pythonic::types::numpy_gexpr<pythonic::types::numpy_iexpr<const pythonic::types::ndarray<float, 3>&>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice> >, pythonic::types::nditerator<pythonic::types::numpy_texpr_2<pythonic::types::ndarray<float, 2> > > >; long unsigned int ...I = {0, 1}; Op = pythonic::operator_::functor::sub; decltype (Op{}(*(get<I>)(pythonic::types::Dereferencer::operator()::iters)...)) = pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::numpy_iexpr<const pythonic::types::numpy_iexpr<const pythonic::types::ndarray<float, 3>&>&>, pythonic::types::contiguous_slice>, pythonic::types::numpy_gexpr<const pythonic::types::ndarray<float, 2>&, pythonic::types::contiguous_slice, long int> >; pythonic::utils::index_sequence<I ...> = pythonic::utils::integer_sequence<long unsigned int, 0, 1>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:58:34:   [ skipping 8 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:171:25:   required from 'struct pythonic::numpy::reduce(const E&, long int, pythonic::types::none_type, pythonic::types::none_type) [with Op = pythonic::operator_::functor::iadd; E = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > > > >; typename std::enable_if<(E:: value != 1), pythonic::types::ndarray<typename E::dtype, (E:: value - 1)> >::type = pythonic::types::ndarray<float, 2>]::<lambda(std::iterator<std::random_access_iterator_tag, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::numpy_iexpr<const pythonic::types::ndarray<float, 3>&>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > > >, long int, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::numpy_iexpr<const pythonic::types::ndarray<float, 3>&>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > > >*, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::numpy_iexpr<const pythonic::types::ndarray<float, 3>&>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > > >&>::value_type)>'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:170:23:   required from 'typename std::enable_if<(E:: value != 1), pythonic::types::ndarray<typename E::dtype, (E:: value - 1)> >::type pythonic::numpy::reduce(const E&, long int, pythonic::types::none_type, pythonic::types::none_type) [with Op = pythonic::operator_::functor::iadd; E = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > > > >; typename std::enable_if<(E:: value != 1), pythonic::types::ndarray<typename E::dtype, (E:: value - 1)> >::type = pythonic::types::ndarray<float, 2>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:21:46:   required from 'decltype (reduce<pythonic::operator_::functor::iadd>((forward<Args>)(pythonic::numpy::sum::args)...)) pythonic::numpy::sum(Args&& ...) [with Args = {pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > > > >, long int}; decltype (reduce<pythonic::operator_::functor::iadd>((forward<Args>)(pythonic::numpy::sum::args)...)) = pythonic::types::ndarray<float, 2>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:24:5:   required from 'decltype (pythonic::numpy::sum((forward<Types>)(pythonic::numpy::functor::sum::operator()::types)...)) pythonic::numpy::functor::sum::operator()(Types&& ...) const [with Types = {pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_gexpr<pythonic::types::ndarray<float, 3>, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice, pythonic::types::contiguous_slice>, pythonic::types::broadcasted<pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> > > > >, long int}; decltype (pythonic::numpy::sum((forward<Types>)(pythonic::numpy::functor::sum::operator()::types)...)) = pythonic::types::ndarray<float, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:59:76:   required from 'typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::operator()(const argument_type0&) const [with argument_type0 = pythonic::types::numpy_texpr<pythonic::types::ndarray<float, 2> >; typename __pythran_pythranized_68c57c1bdbd6ed6769890b5aa793a2dc::pairwise_distance_pythran::type<argument_type0>::result_type = pythonic::types::ndarray<float, 2>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp5qum_0w0.cpp:114:129:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]

# %%
print(pairwise_distance_pythran(args32).dtype)
# %timeit pairwise_distance_pythran(args32)
print(pairwise_distance_pythran(args64).dtype)
# %timeit pairwise_distance_pythran(args64)
# Out:
# float32
# 884 µs ± 2.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# float64
# 912 µs ± 2.98 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# Pythran also automatically handles transposed arguments, without making a copy:

# %%
pairwise_distance_pythran(args64.T)
# Out:
# array([[ 3.69724678,  3.86923677,  3.88354504, ...,  3.77170682,
#          4.49111697,  4.28071042],
#        [ 4.046676  ,  4.22076358,  4.41779641, ...,  4.19698134,
#          4.15956303,  4.1780762 ],
#        [ 3.86027042,  4.04092985,  4.31161638, ...,  4.2475385 ,
#          4.0949077 ,  4.29476303],
#        ...,
#        [ 4.29501873,  4.44832888,  4.13206678, ...,  4.19163173,
#          4.42579207,  3.6608686 ],
#        [ 4.17561149,  4.12818252,  3.92522576, ...,  3.93665455,
#          4.2331271 ,  4.32786092],
#        [ 3.80711773,  4.35833347,  4.3049985 , ...,  4.17900989,
#          4.43317329,  4.04168381]])

# %% [markdown]
# There's more than arrays and scalars in Pythran types. What about... a tuple of tuple of complex numbers, lists and sets?

# %%
# %%pythran
# #pythran export wtf((int, complex128, (int set, int list, int:str dict)))
# def wtf(x):
#     return x

# %%
wtf(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-a98647e8529f> in <module>()
# ----> 1 wtf(1)
#
# TypeError: Invalid argument type for pythranized function `wtf'.
# Candidates are:
#    wtf(decltype(make_tuple(std.declval<long>(), std.declval<std.complex<double>>(), std.declval<decltype(make_tuple(std.declval<set<long>>(), std.declval<list<long>>(), std.declval<dict<long,str>>()))>())))

# %%
strange_arg = 42, 1 + 1j, ({1, 2, 3}, [1, 2,3], {1: 'unan', 2: 'daou', 3: 'tri'})
wtf(strange_arg)
# Out:
# (42, (1+1j), ({1, 2, 3}, [1, 2, 3], {1: 'unan', 2: 'daou', 3: 'tri'}))

# %% [markdown]
# Beware that Pythran works on a copy when passing ``tuple``, ``list``, ``set`` or ``dict`` in the Pythran world (it's ok for ``ndarray`` as it does not copy the whole data):

# %%
wtf(strange_arg) is strange_arg
# Out:
# False

# %% [markdown]
# Sometimes, you feel like using very long function prototypes. In that case use multi-line exports:

# %%
# %%pythran
#
# #pythran export my(bool,
# #                  bool,
# #                  bool,
# #                  bool)
# def my(ga, bu, zo, meu):
#     pass

# %%
my
# Out:
# <function pythranized_91f76c58891b91073f8e4e4dae8d0989.my>

# %%
type(my(True, True, True, True))
# Out:
# NoneType

# %% [markdown]
# Default arguments are taken into account, but they must be exported explictely:

# %%
# %%pythran
# #pythran export pi_numpy_style_pythran_default(int)
# #pythran export pi_numpy_style_pythran_default()
# import numpy as np
# def pi_numpy_style_pythran_default(n=1):
#     step = 1.0 / n
#     x = (np.arange(0, n, dtype=np.float64) + 0.5) * step
#     return step * np.sum(4. / (1. + x ** 2))
# Out:
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/div.hpp:7:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:16:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp: In function 'bool pythonic::operator_::lshift(bool, bool)':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp:21:48: warning: '<<' in boolean context, did you mean '<' ? [-Wint-in-bool-context]
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(lshift, << )
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/overloads.hpp:9:14: note: in definition of macro 'PYTHONIC_OPERATOR_OVERLOAD_IMPL'
#      return a op b;                                                             \
#               ^~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp:21:5: note: in expansion of macro 'DEFINE_ALL_OPERATOR_OVERLOADS_IMPL'
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(lshift, << )
#      ^
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp: In function 'bool pythonic::operator_::mul(bool, bool)':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp:21:45: warning: '*' in boolean context, suggest '&&' instead [-Wint-in-bool-context]
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(mul, *)
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/overloads.hpp:9:14: note: in definition of macro 'PYTHONIC_OPERATOR_OVERLOAD_IMPL'
#      return a op b;                                                             \
#               ^~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp:21:5: note: in expansion of macro 'DEFINE_ALL_OPERATOR_OVERLOADS_IMPL'
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(mul, *)
#      ^
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:38:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:6,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:5,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:18:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::add; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::add, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator+(const E0&, const E1&) [with E0 = pythonic::types::ndarray<double, 1>; E1 = double; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::add, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:54:210:   required from 'typename __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::type<argument_type0>::result_type __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:64:133:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < value; ++i) {
#                          ~~^~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::mul; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator*(const E0&, const E1&) [with E0 = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >; E1 = double; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:54:217:   required from 'typename __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::type<argument_type0>::result_type __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:64:133:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::numpy::functor::square; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_nary_expr.hpp:39:20:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type pythonic::numpy::functor::square::operator()(const E& ...) const [with E = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> >}; typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::square, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:54:124:   required from 'typename __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::type<argument_type0>::result_type __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:64:133:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::add; Args = {pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::add, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator+(const E0&, const E1&) [with E0 = double; E1 = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > >; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::add, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:54:88:   required from 'typename __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::type<argument_type0>::result_type __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:64:133:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<Op, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::div; Args = {pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::div, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator/(const E0&, const E1&) [with E0 = double; E1 = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::div, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/div.hpp:22:16:   required from 'typename std::enable_if<((! std::is_fundamental<_Tp>::value) || (! std::is_fundamental<B>::value)), decltype ((a / b))>::type pythonic::operator_::div(const A&, const B&) [with A = double; B = pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > >; typename std::enable_if<((! std::is_fundamental<_Tp>::value) || (! std::is_fundamental<B>::value)), decltype ((a / b))>::type = pythonic::types::numpy_expr<pythonic::operator_::functor::div, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::broadcast<double, double>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::add, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::types::broadcast<double, double> > > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:54:77:   required from 'typename __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::type<argument_type0>::result_type __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:64:133:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/ndarray.hpp:17:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/numpy/reduce.hpp:4,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/numpy/sum.hpp:4,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:13:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp: In instantiation of 'pythonic::types::raw_array<T>::raw_array(size_t) [with T = double; size_t = long unsigned int]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:26:71:   required from 'pythonic::utils::shared_ref<T>::memory::memory(Types&& ...) [with Types = {int}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:43:15:   required from 'pythonic::utils::shared_ref<T>::shared_ref(Types&& ...) [with Types = {int}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:306:73:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::array<long int, M>&, pythonic::types::none_type) [with T = double; long unsigned int N = 1]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/arange.hpp:20:28:   required from 'pythonic::types::ndarray<typename dtype::type, 1> pythonic::numpy::arange(T, U, S, dtype) [with T = long int; U = long int; S = long int; dtype = pythonic::numpy::functor::float64; typename dtype::type = double]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/arange.hpp:38:5:   required from 'decltype (pythonic::numpy::arange((forward<Types>)(pythonic::numpy::functor::arange::operator()::types)...)) pythonic::numpy::functor::arange::operator()(Types&& ...) const [with Types = {long int, const long int&, long int, pythonic::numpy::functor::float64}; decltype (pythonic::numpy::arange((forward<Types>)(pythonic::numpy::functor::arange::operator()::types)...)) = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:54:161:   required from 'typename __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::type<argument_type0>::result_type __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::operator()(const argument_type0&) const [with argument_type0 = long int; typename __pythran_pythranized_fc3da44a1f7388c6e117dac00eca4acc::pi_numpy_style_pythran_default::type<argument_type0>::result_type = double]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:64:133:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:26:10: warning: 'pythonic::types::raw_array<double>::data' will be initialized after [-Wreorder]
#        T *data;
#           ^~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:21:12: warning:   'bool pythonic::types::raw_array<double>::external' [-Wreorder]
#        bool external;
#             ^~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:19:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/reduce.hpp:6,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/numpy/sum.hpp:5,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmpavrvsnzu.cpp:18:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp:22:5: warning:   when initialized here [-Wreorder]
#      raw_array<T>::raw_array(size_t n)
#      ^~~~~~~~~~~~

# %%
pi_numpy_style_pythran_default()
# Out:
# 3.2

# %%
pi_numpy_style_pythran_default(10)
# Out:
# 3.2

# %% [markdown]
# # Compilation of Numpy Expressions
#
# Pythran is well aware of high-level numpy expressions. Consider this function:

# %%
import numpy as np
def vibr_energy(harmonic, anharmonic, i):
    return np.exp(-harmonic * i - anharmonic * (i ** 2))

dat0, dat1 = np.random.random(1000000), np.random.random(1000000)

# %%
# %timeit vibr_energy(dat0, dat1, 3.)
# Out:
# 12.7 ms ± 99.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# A typical way to optimize it would be to use the ``numexpr`` package:

# %%
import numexpr as ne
def vibr_energy_numexpr(harmonic, anharmonic, i):
    return ne.evaluate('exp(-harmonic * i - anharmonic * (i ** 2))')

# %%
vibr_energy_numexpr(dat0, dat1, 3.)  # maybe ne has a cache?
# %timeit vibr_energy_numexpr(dat0, dat1, 3.)
# Out:
# 4.02 ms ± 12.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Pythran implements (roughly) the same optimizations as ``numexpr`` does:

# %%
# %%pythran -DUSE_BOOST_SIMD -march=native -Ofast -fopenmp
#
# import numpy as np
# #pythran export vibr_energy_pythran(float[], float[], float)
#
# def vibr_energy_pythran(harmonic, anharmonic, i):
#
#     return np.exp(-harmonic * i - anharmonic * (i ** 2))
# Out:
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/add.hpp:7:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_operators.hpp:7,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:1132,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:12:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp: In function 'bool pythonic::operator_::lshift(bool, bool)':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp:21:48: warning: '<<' in boolean context, did you mean '<' ? [-Wint-in-bool-context]
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(lshift, << )
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/overloads.hpp:9:14: note: in definition of macro 'PYTHONIC_OPERATOR_OVERLOAD_IMPL'
#      return a op b;                                                             \
#               ^~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp:21:5: note: in expansion of macro 'DEFINE_ALL_OPERATOR_OVERLOADS_IMPL'
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(lshift, << )
#      ^
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp: In function 'bool pythonic::operator_::mul(bool, bool)':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp:21:45: warning: '*' in boolean context, suggest '&&' instead [-Wint-in-bool-context]
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(mul, *)
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/overloads.hpp:9:14: note: in definition of macro 'PYTHONIC_OPERATOR_OVERLOAD_IMPL'
#      return a op b;                                                             \
#               ^~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp:21:5: note: in expansion of macro 'DEFINE_ALL_OPERATOR_OVERLOADS_IMPL'
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(mul, *)
#      ^
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:38:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:12:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::ndarray<double, 1>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::neg; Args = {pythonic::types::ndarray<double, 1>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_unary_op.hpp:13:15:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<E>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, E> >::type pythonic::types::operator-(const E&) [with E = pythonic::types::ndarray<double, 1>; typename std::enable_if<pythonic::types::valid_numexpr_parameters<E>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, E> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:44:47:   required from 'typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < value; ++i) {
#                          ~~^~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::mul; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator*(const E0&, const E1&) [with E0 = pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >; E1 = double; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:44:58:   required from 'typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::mul; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator*(const E0&, const E1&) [with E0 = pythonic::types::ndarray<double, 1>; E1 = double; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:44:77:   required from 'typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::sub; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator-(const E0&, const E1&) [with E0 = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >; E1 = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:44:63:   required from 'typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::numpy::functor::exp; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_nary_expr.hpp:39:20:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::exp, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type pythonic::numpy::functor::exp::operator()(const E& ...) const [with E = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >}; typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::exp, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:44:43:   required from 'typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/ndarray.hpp:17:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:10:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp: In instantiation of 'pythonic::types::raw_array<T>::raw_array(size_t) [with T = double; size_t = long unsigned int]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:26:71:   required from 'pythonic::utils::shared_ref<T>::memory::memory(Types&& ...) [with Types = {long int}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:43:15:   required from 'pythonic::utils::shared_ref<T>::shared_ref(Types&& ...) [with Types = {long int}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:366:40:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::exp; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >}; T = double; long unsigned int N = 1]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:44:118:   required from 'typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:26:10: warning: 'pythonic::types::raw_array<double>::data' will be initialized after [-Wreorder]
#        T *data;
#           ^~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:21:12: warning:   'bool pythonic::types::raw_array<double>::external' [-Wreorder]
#        bool external;
#             ^~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:19:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:12:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp:22:5: warning:   when initialized here [-Wreorder]
#      raw_array<T>::raw_array(size_t n)
#      ^~~~~~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:14:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:12:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp: In instantiation of 'void pythonic::utils::vbroadcast_copy(E&&, const F&) [with vectorizer = pythonic::types::vectorizer_nobroadcast; E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:165:62:   required from 'void pythonic::utils::_broadcast_copy<pythonic::types::vectorizer_nobroadcast, 1, 0>::operator()(E&&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:190:65:   required from 'void pythonic::utils::broadcast_copy_dispatcher<E, F, N, D, true>::operator()(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; long unsigned int D = 0]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:199:59:   required from 'E& pythonic::utils::broadcast_copy(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; long unsigned int D = 0; bool vector_form = true]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:358:79:   required from 'void pythonic::types::ndarray<T, N>::initialize_from_expr(const E&) [with E = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; T = double; long unsigned int N = 1]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:368:27:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::exp; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >}; T = double; long unsigned int N = 1]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:44:118:   required from 'typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:131:28: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (long i = 0; i < bound * vN; i += vN, ++oiter)
#                           ~~^~~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:144:9: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (size_t i = other_size; i < self_size; i += other_size)
#          ^~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:148:39: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (size_t i = other_size; i < self_size; i += other_size)
#                                      ~~^~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp: In instantiation of 'void pythonic::utils::vbroadcast_copy(E&&, const F&) [with vectorizer = pythonic::types::vectorizer; E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:157:50:   required from 'void pythonic::utils::_broadcast_copy<pythonic::types::vectorizer, 1, 0>::operator()(E&&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:192:53:   required from 'void pythonic::utils::broadcast_copy_dispatcher<E, F, N, D, true>::operator()(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; long unsigned int D = 0]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:199:59:   required from 'E& pythonic::utils::broadcast_copy(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; long unsigned int D = 0; bool vector_form = true]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:358:79:   required from 'void pythonic::types::ndarray<T, N>::initialize_from_expr(const E&) [with E = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; T = double; long unsigned int N = 1]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:368:27:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::exp; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >}; T = double; long unsigned int N = 1]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:44:118:   required from 'typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:131:28: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (long i = 0; i < bound * vN; i += vN, ++oiter)
#                           ~~^~~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:144:9: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (size_t i = other_size; i < self_size; i += other_size)
#          ^~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:148:39: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (size_t i = other_size; i < self_size; i += other_size)
#                                      ~~^~~~~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/ndarray.hpp:17:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:10:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp: In instantiation of 'pythonic::types::raw_array<T>::raw_array(T*, pythonic::types::ownership) [with T = double]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:26:71:   required from 'pythonic::utils::shared_ref<T>::memory::memory(Types&& ...) [with Types = {double*&, pythonic::types::ownership&}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:43:15:   required from 'pythonic::utils::shared_ref<T>::shared_ref(Types&& ...) [with Types = {double*&, pythonic::types::ownership&}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:321:51:   required from 'pythonic::types::ndarray<T, N>::ndarray(T*, const S*, pythonic::types::ownership) [with S = long int; T = double; long unsigned int N = 1]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:331:52:   required from 'pythonic::types::ndarray<T, N>::ndarray(T*, const S*, PyObject*) [with S = long int; T = double; long unsigned int N = 1; PyObject = _object]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:1423:26:   required from 'static pythonic::types::ndarray<T, N> pythonic::from_python<pythonic::types::ndarray<T, N> >::convert(PyObject*) [with T = double; long unsigned int N = 1; PyObject = _object]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/python/core.hpp:31:43:   required from 'T from_python(PyObject*) [with T = pythonic::types::ndarray<double, 1>; PyObject = _object]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:74:106:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:26:10: warning: 'pythonic::types::raw_array<double>::data' will be initialized after [-Wreorder]
#        T *data;
#           ^~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:21:12: warning:   'bool pythonic::types::raw_array<double>::external' [-Wreorder]
#        bool external;
#             ^~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:19:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:12:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp:28:5: warning:   when initialized here [-Wreorder]
#      raw_array<T>::raw_array(T *d, ownership o)
#      ^~~~~~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/ndarray.hpp:36:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:10:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp: In instantiation of 'pythonic::types::numpy_expr_simd_iterator<E, Op, SIters, Iters>::numpy_expr_simd_iterator(const pythonic::types::numpy_expr_simd_iterator<E, Op, SIters, Iters>&) [with E = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; Op = pythonic::numpy::functor::exp; SIters = std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::sub, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::neg, const double*>, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, const double*, pythonic::types::const_broadcast_iterator<double> > > >; Iters = {pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >, pythonic::operator_::functor::sub, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::neg, const double*>, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, const double*, pythonic::types::const_broadcast_iterator<double> > >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::neg, const double*>, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::operator_::functor::neg, std::tuple<const double*>, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> > >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:119:12:   required from 'void pythonic::utils::vbroadcast_copy(E&&, const F&) [with vectorizer = pythonic::types::vectorizer; E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:157:50:   required from 'void pythonic::utils::_broadcast_copy<pythonic::types::vectorizer, 1, 0>::operator()(E&&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:192:53:   required from 'void pythonic::utils::broadcast_copy_dispatcher<E, F, N, D, true>::operator()(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; long unsigned int D = 0]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:199:59:   required from 'E& pythonic::utils::broadcast_copy(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; long unsigned int D = 0; bool vector_form = true]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:358:79:   required from 'void pythonic::types::ndarray<T, N>::initialize_from_expr(const E&) [with E = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; T = double; long unsigned int N = 1]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:368:27:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::exp; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >}; T = double; long unsigned int N = 1]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:44:118:   required from 'typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:54:145:   required from here
# ...
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:176:14: warning: 'pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >::siters_' will be initialized after [-Wreorder]
#        SIters siters_;
#               ^~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:175:28: warning:   'std::tuple<pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > > pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >::iters_' [-Wreorder]
#        std::tuple<Iters...> iters_;
#                             ^~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:178:7: warning:   when initialized here [-Wreorder]
#        numpy_expr_simd_iterator(std::array<long, sizeof...(Iters)> steps,
#        ^~~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp: In instantiation of 'pythonic::types::numpy_expr_simd_iterator<E, Op, SIters, Iters>::numpy_expr_simd_iterator(std::array<long int, sizeof... (Iters)>, const SIters&, Iters ...) [with E = pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >; Op = pythonic::operator_::functor::neg; SIters = std::tuple<const double*>; Iters = {pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:208:55:   required from 'pythonic::types::numpy_expr<O, Args>::simd_iterator pythonic::types::numpy_expr<O, Args>::_vbegin(pythonic::types::vectorize, pythonic::utils::index_sequence<S ...>) const [with long unsigned int ...I = {0}; Op = pythonic::operator_::functor::neg; Args = {pythonic::types::ndarray<double, 1>}; pythonic::types::numpy_expr<O, Args>::simd_iterator = pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::operator_::functor::neg, std::tuple<const double*>, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> > >; pythonic::utils::index_sequence<S ...> = pythonic::utils::integer_sequence<long unsigned int, 0>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:215:21:   required from 'pythonic::types::numpy_expr<O, Args>::simd_iterator pythonic::types::numpy_expr<O, Args>::vbegin(pythonic::types::vectorize) const [with Op = pythonic::operator_::functor::neg; Args = {pythonic::types::ndarray<double, 1>}; pythonic::types::numpy_expr<O, Args>::simd_iterator = pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::operator_::functor::neg, std::tuple<const double*>, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> > >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:208:55:   required from 'pythonic::types::numpy_expr<O, Args>::simd_iterator pythonic::types::numpy_expr<O, Args>::_vbegin(pythonic::types::vectorize, pythonic::utils::index_sequence<S ...>) const [with long unsigned int ...I = {0, 1}; Op = pythonic::operator_::functor::mul; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double>}; pythonic::types::numpy_expr<O, Args>::simd_iterator = pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::neg, const double*>, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::operator_::functor::neg, std::tuple<const double*>, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> > >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >; pythonic::utils::index_sequence<S ...> = pythonic::utils::integer_sequence<long unsigned int, 0, 1>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:215:21:   required from 'pythonic::types::numpy_expr<O, Args>::simd_iterator pythonic::types::numpy_expr<O, Args>::vbegin(pythonic::types::vectorize) const [with Op = pythonic::operator_::functor::mul; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double>}; pythonic::types::numpy_expr<O, Args>::simd_iterator = pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::neg, const double*>, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::operator_::functor::neg, std::tuple<const double*>, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> > >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:208:55:   required from 'pythonic::types::numpy_expr<O, Args>::simd_iterator pythonic::types::numpy_expr<O, Args>::_vbegin(pythonic::types::vectorize, pythonic::utils::index_sequence<S ...>) const [with long unsigned int ...I = {0, 1}; Op = pythonic::operator_::functor::sub; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >}; pythonic::types::numpy_expr<O, Args>::simd_iterator = pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >, pythonic::operator_::functor::sub, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::neg, const double*>, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::mul, const double*, pythonic::types::const_broadcast_iterator<double> > >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<pythonic::types::numpy_expr_iterator<pythonic::operator_::functor::neg, const double*>, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::operator_::functor::neg, std::tuple<const double*>, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> > >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > >, pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >, pythonic::operator_::functor::mul, std::tuple<const double*, pythonic::types::const_broadcast_iterator<double> >, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> >, pythonic::types::const_broadcast_iterator<boost::simd::pack<double, 4, boost::simd::avx_> > > >; pythonic::utils::index_sequence<S ...> = pythonic::utils::integer_sequence<long unsigned int, 0, 1>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:215:21:   [ skipping 6 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:192:53:   required from 'void pythonic::utils::broadcast_copy_dispatcher<E, F, N, D, true>::operator()(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; long unsigned int D = 0]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:199:59:   required from 'E& pythonic::utils::broadcast_copy(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; long unsigned int D = 0; bool vector_form = true]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:358:79:   required from 'void pythonic::types::ndarray<T, N>::initialize_from_expr(const E&) [with E = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; T = double; long unsigned int N = 1]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:368:27:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::exp; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >}; T = double; long unsigned int N = 1]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:44:118:   required from 'typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_4c65c70e2018b17433636227c0800977::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp2v27jsco.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:176:14: warning: 'pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::operator_::functor::neg, std::tuple<const double*>, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> > >::siters_' will be initialized after [-Wreorder]
#        SIters siters_;
#               ^~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:175:28: warning:   'std::tuple<pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> > > pythonic::types::numpy_expr_simd_iterator<pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::operator_::functor::neg, std::tuple<const double*>, pythonic::types::const_simd_nditerator<pythonic::types::ndarray<double, 1> > >::iters_' [-Wreorder]
#        std::tuple<Iters...> iters_;
#                             ^~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/numpy_expr.hpp:178:7: warning:   when initialized here [-Wreorder]
#        numpy_expr_simd_iterator(std::array<long, sizeof...(Iters)> steps,
#        ^~~~~~~~~~~~~~~~~~~~~~~~

# %%
# %timeit vibr_energy_pythran(dat0, dat1, 3.)
# Out:
# 2.63 ms ± 23.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Remember that Pythran can handle polymorphic code? Then let's try:

# %%
# %%pythran
# import numpy as np
# #pythran export vibr_energy_pythran(float[], float[], float)
# #pythran export vibr_energy_pythran(float[], float[], float[])
# def vibr_energy_pythran(harmonic, anharmonic, i):
#     return np.exp(-harmonic * i - anharmonic * (i ** 2))
# Out:
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/add.hpp:7:0,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_operators.hpp:7,
#                  from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:1132,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:12:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp: In function 'bool pythonic::operator_::lshift(bool, bool)':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp:21:48: warning: '<<' in boolean context, did you mean '<' ? [-Wint-in-bool-context]
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(lshift, << )
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/overloads.hpp:9:14: note: in definition of macro 'PYTHONIC_OPERATOR_OVERLOAD_IMPL'
#      return a op b;                                                             \
#               ^~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/lshift.hpp:21:5: note: in expansion of macro 'DEFINE_ALL_OPERATOR_OVERLOADS_IMPL'
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(lshift, << )
#      ^
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp: In function 'bool pythonic::operator_::mul(bool, bool)':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp:21:45: warning: '*' in boolean context, suggest '&&' instead [-Wint-in-bool-context]
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(mul, *)
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/overloads.hpp:9:14: note: in definition of macro 'PYTHONIC_OPERATOR_OVERLOAD_IMPL'
#      return a op b;                                                             \
#               ^~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/operator_/mul.hpp:21:5: note: in expansion of macro 'DEFINE_ALL_OPERATOR_OVERLOADS_IMPL'
#      DEFINE_ALL_OPERATOR_OVERLOADS_IMPL(mul, *)
#      ^
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:38:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:12:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::ndarray<double, 1>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::neg; Args = {pythonic::types::ndarray<double, 1>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_unary_op.hpp:13:15:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<E>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, E> >::type pythonic::types::operator-(const E&) [with E = pythonic::types::ndarray<double, 1>; typename std::enable_if<pythonic::types::valid_numexpr_parameters<E>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, E> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:47:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = pythonic::types::ndarray<double, 1>; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < value; ++i) {
#                          ~~^~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::mul; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator*(const E0&, const E1&) [with E0 = pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >; E1 = pythonic::types::ndarray<double, 1>; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:58:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = pythonic::types::ndarray<double, 1>; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::mul; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator*(const E0&, const E1&) [with E0 = pythonic::types::ndarray<double, 1>; E1 = pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> >; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:77:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = pythonic::types::ndarray<double, 1>; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::sub; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator-(const E0&, const E1&) [with E0 = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >; E1 = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > >; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:63:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = pythonic::types::ndarray<double, 1>; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::numpy::functor::exp; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_nary_expr.hpp:39:20:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::exp, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type pythonic::numpy::functor::exp::operator()(const E& ...) const [with E = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > >}; typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::exp, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:43:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = pythonic::types::ndarray<double, 1>; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::mul; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator*(const E0&, const E1&) [with E0 = pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >; E1 = double; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:58:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:69:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double>}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::mul; Args = {pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double>}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator*(const E0&, const E1&) [with E0 = pythonic::types::ndarray<double, 1>; E1 = double; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:77:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:69:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::operator_::functor::sub; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_binary_op.hpp:16:22:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type pythonic::types::operator-(const E0&, const E1&) [with E0 = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >; E1 = pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> >; typename std::enable_if<pythonic::types::valid_numexpr_parameters<T0, T1>::value, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, typename pythonic::types::adapt_type<E0, E1>::type, typename pythonic::types::adapt_type<E1, E0>::type> >::type = pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:63:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:69:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp: In instantiation of 'pythonic::types::array<long int, M> pythonic::types::details::init_shape(const Args& ...) [with long unsigned int value = 1; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >}]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:41:59:   required from 'pythonic::types::numpy_expr<O, Args>::numpy_expr(const Args& ...) [with Op = pythonic::numpy::functor::exp; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >}]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_nary_expr.hpp:39:20:   required from 'typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::exp, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type pythonic::numpy::functor::exp::operator()(const E& ...) const [with E = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >}; typename std::enable_if<pythonic::types::valid_numexpr_parameters<Types>::value, pythonic::types::numpy_expr<pythonic::numpy::functor::exp, typename pythonic::types::adapt_type<E, E ...>::type ...> >::type = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:43:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:69:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/numpy_expr.hpp:22:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/ndarray.hpp:17:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:10:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp: In instantiation of 'pythonic::types::raw_array<T>::raw_array(size_t) [with T = double; size_t = long unsigned int]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:26:71:   required from 'pythonic::utils::shared_ref<T>::memory::memory(Types&& ...) [with Types = {long int}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:43:15:   required from 'pythonic::utils::shared_ref<T>::shared_ref(Types&& ...) [with Types = {long int}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:366:40:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::exp; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > >}; T = double; long unsigned int N = 1]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:118:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = pythonic::types::ndarray<double, 1>; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:26:10: warning: 'pythonic::types::raw_array<double>::data' will be initialized after [-Wreorder]
#        T *data;
#           ^~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:21:12: warning:   'bool pythonic::types::raw_array<double>::external' [-Wreorder]
#        bool external;
#             ^~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:19:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:12:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp:22:5: warning:   when initialized here [-Wreorder]
#      raw_array<T>::raw_array(size_t n)
#      ^~~~~~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:14:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:12:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp: In instantiation of 'void pythonic::utils::_broadcast_copy<vectorizer, N, 0>::operator()(E&&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > > >; long unsigned int N = 1; vectorizer = pythonic::types::vectorizer_nobroadcast]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:190:65:   required from 'void pythonic::utils::broadcast_copy_dispatcher<E, F, N, D, true>::operator()(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > > >; long unsigned int N = 1; long unsigned int D = 0]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:199:59:   required from 'E& pythonic::utils::broadcast_copy(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > > >; long unsigned int N = 1; long unsigned int D = 0; bool vector_form = true]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:358:79:   required from 'void pythonic::types::ndarray<T, N>::initialize_from_expr(const E&) [with E = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > > >; T = double; long unsigned int N = 1]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:368:27:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::exp; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > >}; T = double; long unsigned int N = 1]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:118:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = pythonic::types::ndarray<double, 1>; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:78:41: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#            for (size_t i = other_size; i < self_size; i += other_size)
#                                        ~~^~~~~~~~~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp: In instantiation of 'void pythonic::utils::_broadcast_copy<vectorizer, N, 0>::operator()(E&&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > > >; long unsigned int N = 1; vectorizer = pythonic::types::vectorizer]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:192:53:   required from 'void pythonic::utils::broadcast_copy_dispatcher<E, F, N, D, true>::operator()(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > > >; long unsigned int N = 1; long unsigned int D = 0]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:199:59:   required from 'E& pythonic::utils::broadcast_copy(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > > >; long unsigned int N = 1; long unsigned int D = 0; bool vector_form = true]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:358:79:   required from 'void pythonic::types::ndarray<T, N>::initialize_from_expr(const E&) [with E = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > > >; T = double; long unsigned int N = 1]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:368:27:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::exp; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::ndarray<double, 1> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::numpy_expr<pythonic::numpy::functor::square, pythonic::types::ndarray<double, 1> > > >}; T = double; long unsigned int N = 1]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:118:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = pythonic::types::ndarray<double, 1>; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:54:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:78:41: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp: In instantiation of 'void pythonic::utils::_broadcast_copy<vectorizer, N, 0>::operator()(E&&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; vectorizer = pythonic::types::vectorizer_nobroadcast]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:190:65:   required from 'void pythonic::utils::broadcast_copy_dispatcher<E, F, N, D, true>::operator()(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; long unsigned int D = 0]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:199:59:   required from 'E& pythonic::utils::broadcast_copy(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; long unsigned int D = 0; bool vector_form = true]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:358:79:   required from 'void pythonic::types::ndarray<T, N>::initialize_from_expr(const E&) [with E = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; T = double; long unsigned int N = 1]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:368:27:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::exp; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >}; T = double; long unsigned int N = 1]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:118:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:69:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:78:41: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp: In instantiation of 'void pythonic::utils::_broadcast_copy<vectorizer, N, 0>::operator()(E&&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; vectorizer = pythonic::types::vectorizer]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:192:53:   required from 'void pythonic::utils::broadcast_copy_dispatcher<E, F, N, D, true>::operator()(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; long unsigned int D = 0]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:199:59:   required from 'E& pythonic::utils::broadcast_copy(E&, const F&) [with E = pythonic::types::ndarray<double, 1>&; F = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; long unsigned int N = 1; long unsigned int D = 0; bool vector_form = true]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:358:79:   required from 'void pythonic::types::ndarray<T, N>::initialize_from_expr(const E&) [with E = pythonic::types::numpy_expr<pythonic::numpy::functor::exp, pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > > >; T = double; long unsigned int N = 1]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:368:27:   required from 'pythonic::types::ndarray<T, N>::ndarray(const pythonic::types::numpy_expr<Op, Args ...>&) [with Op = pythonic::numpy::functor::exp; Args = {pythonic::types::numpy_expr<pythonic::operator_::functor::sub, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::numpy_expr<pythonic::operator_::functor::neg, pythonic::types::ndarray<double, 1> >, pythonic::types::broadcast<double, double> >, pythonic::types::numpy_expr<pythonic::operator_::functor::mul, pythonic::types::ndarray<double, 1>, pythonic::types::broadcast<double, double> > >}; T = double; long unsigned int N = 1]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:44:118:   required from 'typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::operator()(const argument_type0&, const argument_type1&, const argument_type2&) const [with argument_type0 = pythonic::types::ndarray<double, 1>; argument_type1 = pythonic::types::ndarray<double, 1>; argument_type2 = double; typename __pythran_pythranized_6cb952f1a3f30168120d19b6890c13d4::vibr_energy_pythran::type<argument_type0, argument_type1, argument_type2>::result_type = pythonic::types::ndarray<double, 1>]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:69:145:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/broadcast_copy.hpp:78:41: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/ndarray.hpp:17:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:10:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp: In instantiation of 'pythonic::types::raw_array<T>::raw_array(T*, pythonic::types::ownership) [with T = double]':
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:26:71:   required from 'pythonic::utils::shared_ref<T>::memory::memory(Types&& ...) [with Types = {double*&, pythonic::types::ownership&}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/utils/shared_ref.hpp:43:15:   required from 'pythonic::utils::shared_ref<T>::shared_ref(Types&& ...) [with Types = {double*&, pythonic::types::ownership&}; T = pythonic::types::raw_array<double>]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:321:51:   required from 'pythonic::types::ndarray<T, N>::ndarray(T*, const S*, pythonic::types::ownership) [with S = long int; T = double; long unsigned int N = 1]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:331:52:   required from 'pythonic::types::ndarray<T, N>::ndarray(T*, const S*, PyObject*) [with S = long int; T = double; long unsigned int N = 1; PyObject = _object]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:1423:26:   required from 'static pythonic::types::ndarray<T, N> pythonic::from_python<pythonic::types::ndarray<T, N> >::convert(PyObject*) [with T = double; long unsigned int N = 1; PyObject = _object]'
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/python/core.hpp:31:43:   required from 'T from_python(PyObject*) [with T = pythonic::types::ndarray<double, 1>; PyObject = _object]'
# /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:89:106:   required from here
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:26:10: warning: 'pythonic::types::raw_array<double>::data' will be initialized after [-Wreorder]
#        T *data;
#           ^~~~
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/include/types/raw_array.hpp:21:12: warning:   'bool pythonic::types::raw_array<double>::external' [-Wreorder]
#        bool external;
#             ^~~~~~~~
# In file included from /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/ndarray.hpp:19:0,
#                  from /var/folders/mw/nwq5qyg56fl585pb9jw81_qc0000gn/T/tmp7uvn99wn.cpp:12:
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/pythonic/types/raw_array.hpp:28:5: warning:   when initialized here [-Wreorder]
#      raw_array<T>::raw_array(T *d, ownership o)
#      ^~~~~~~~~~~~

# %%
# %timeit vibr_energy_pythran(dat0, dat1, dat0)
# Out:
# 14.4 ms ± 123 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Broadcasting on the way!

# %% [markdown]
# # Using Pythran from the Command Line
#
# Pythran can be used without a Jupyter notebook! It requires you to
#
# 1. Write your code to Pythranize into a seperate file;
# 2. Call the Pythran compiler.

# %%
# %%file scrabble.py
#pythran export scrabble_score(str, str:int dict)
def scrabble_score(word, scoretable):
    score = 0
    for letter in word:
        if letter in scoretable:
            score += scoretable[letter]
    return score
# Out:
# Overwriting scrabble.py

# %% [markdown]
# Using the package API, or simply ``pythran scrabble.py``

# %%
# !python -m pythran.run -v scrabble.py
# Out:
# /usr/bin/python: No module named pythran

# %%
import scrabble

# %%
scrabble.__file__
# Out:
# '/Users/navaro/PycharmProjects/notebooks-python/scrabble.so'

# %%
scrabble.scrabble_score("hello", {"h": 4, "e": 1, "l": 1, "o": 1})
# Out:
# 8

# %% [markdown]
# # Using Pythran with distutils
#
# Pythran provides some facilities for distutils integration, in the form of a ``PythranExtension``:

# %%
# %%file setup.py
from distutils.core import Extension
from setuptools import setup, dist

dist.Distribution(dict(setup_requires='pythran'))

from pythran import PythranExtension
module1 = PythranExtension('demo', sources = ['scrabble.py'])

setup(name = 'demo',
      version = '1.0',
      description = 'This is a demo package',
      ext_modules = [module1])
# Out:
# Writing setup.py

# %%
# !python3 setup.py build -v
# Out:
# WARNING  Pythran support disabled for module: omp
# running build
# running build_ext
# building 'demo' extension
# C compiler: gcc-7 -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes
#
# creating build/temp.macosx-10.12-x86_64-3.6
# compile options: '-DUSE_GMP -DBOOST_SIMD_CONFIG_SUPPORT_POSIX_MEMALIGN -DENABLE_PYTHON_MODULE -D__PYTHRAN__=3 -DPYTHRAN_BLAS_OPENBLAS -I/usr/local/opt/openblas/include -I/usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran -I/usr/local/lib/python3.6/site-packages/numpy/core/include -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/include/python3.6m -c'
# extra options: '-std=c++11 -fno-math-errno'
# gcc-7: scrabble.cpp
# cc1plus: warning: command line option '-Wstrict-prototypes' is valid for C/ObjC but not for C++
# creating build/lib.macosx-10.12-x86_64-3.6
# g++-7 -bundle -undefined dynamic_lookup build/temp.macosx-10.12-x86_64-3.6/scrabble.o -L/usr/local/opt/openblas/lib -L/usr/local/lib -L/usr/local/opt/openssl/lib -L/usr/local/opt/sqlite/lib -lgmp -lgmpxx -o build/lib.macosx-10.12-x86_64-3.6/demo.cpython-36m-darwin.so

# %%
# !python3 setup.py sdist
# Out:
# WARNING  Pythran support disabled for module: omp
# running sdist
# running egg_info
# creating demo.egg-info
# writing demo.egg-info/PKG-INFO
# writing dependency_links to demo.egg-info/dependency_links.txt
# writing top-level names to demo.egg-info/top_level.txt
# writing manifest file 'demo.egg-info/SOURCES.txt'
# reading manifest file 'demo.egg-info/SOURCES.txt'
# writing manifest file 'demo.egg-info/SOURCES.txt'
# running check
# warning: check: missing required meta-data: url
#
# warning: check: missing meta-data: either (author and author_email) or (maintainer and maintainer_email) must be supplied
#
# creating demo-1.0
# creating demo-1.0/demo.egg-info
# copying files to demo-1.0...
# copying README.md -> demo-1.0
# copying scrabble.cpp -> demo-1.0
# copying setup.py -> demo-1.0
# copying demo.egg-info/PKG-INFO -> demo-1.0/demo.egg-info
# copying demo.egg-info/SOURCES.txt -> demo-1.0/demo.egg-info
# copying demo.egg-info/dependency_links.txt -> demo-1.0/demo.egg-info
# copying demo.egg-info/top_level.txt -> demo-1.0/demo.egg-info
# Writing demo-1.0/setup.cfg
# creating dist
# Creating tar archive
# removing 'demo-1.0' (and everything under it)

# %%
# !tar tzf dist/demo-1.0.tar.gz
# Out:
# demo-1.0/
# demo-1.0/demo.egg-info/
# demo-1.0/demo.egg-info/dependency_links.txt
# demo-1.0/demo.egg-info/PKG-INFO
# demo-1.0/demo.egg-info/SOURCES.txt
# demo-1.0/demo.egg-info/top_level.txt
# demo-1.0/PKG-INFO
# demo-1.0/README.md
# demo-1.0/scrabble.cpp
# demo-1.0/setup.cfg
# demo-1.0/setup.py

# %% [markdown]
# # Getting Help
#
# - GitHub: https://github.com/serge-sans-paille/pythran
# - Mailing list: http://www.freelists.org/list/pythran
# - IRC: #pythran on FreeNode
# - StackOverflow: http://stackoverflow.com/questions/tagged/pythran

# %% [markdown]
# # Misc
#
# Things you probably don't want to know, but they were fun to implement, so let's talk about them anyway :-)

# %% [markdown]
# ## Functions as regular values

# %%
# %%pythran
# #pythran export modify(int, str)
# actions = {"increase": lambda x: x + 1,
#            "decrease": lambda x: x - 1}
#
# def modify(value, action):
#     what = actions[action]
#     return what(value)

# %%
modify(1, "increase")
# Out:
# 2

# %% [markdown]
# Passing functions in and out is not supported though.

# %% [markdown]
# ## Big Numbers
#
# Not widely supported, but it works for simple examples.

# %%
# %%pythran
# #pythran export factorize_naive(long)
# def factorize_naive(n):
#     if n < 2:
#         return []
#
#     factors = []
#
#     p = 2
#
#     while True:
#         if n == 1:
#             return factors
#
#         r = n % p
#         if r == 0:
#             factors.append(p)
#             n = n / p
#         elif p * p >= n:
#             factors.append(n)
#             return factors
#         elif p > 2:
#             # Advance in steps of 2 over odd numbers
#             p += 2
#         else:
#             # If p == 2, get to 3
#             p += 1
#     assert False, "unreachable"
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-57-28510ce96990> in <module>()
# ----> 1 get_ipython().run_cell_magic('pythran', '', '#pythran export factorize_naive(long)\ndef factorize_naive(n):\n    if n < 2:\n        return []\n    \n    factors = []\n    \n    p = 2\n\n    while True:\n        if n == 1:\n            return factors\n\n        r = n % p\n        if r == 0:\n            factors.append(p)\n            n = n / p\n        elif p * p >= n:\n            factors.append(n)\n            return factors\n        elif p > 2:\n            # Advance in steps of 2 over odd numbers\n            p += 2\n        else:\n            # If p == 2, get to 3\n            p += 1\n    assert False, "unreachable"')
#
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2129             magic_arg_s = self.var_expand(line, stack_depth)
#    2130             with self.builtin_trap:
# -> 2131                 result = fn(magic_arg_s, cell)
#    2132             return result
#    2133
#
# <decorator-gen-573> in pythran(self, line, cell)
#
# /usr/local/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/magic.py in pythran(self, line, cell)
#      69         m.update(cell.encode('utf-8'))
#      70         module_name = "pythranized_" + m.hexdigest()
# ---> 71         module_path = pythran.compile_pythrancode(module_name, cell, **kwargs)
#      72         module = imp.load_dynamic(module_name, module_path)
#      73         self._import_all(module)
#
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/toolchain.py in compile_pythrancode(module_name, pythrancode, specs, opts, cpponly, output_file, **kwargs)
#     362
#     363     # Generate C++, get a PythonModule object
# --> 364     module, error_checker = generate_cxx(module_name, pythrancode, specs, opts)
#     365
#     366     if 'ENABLE_PYTHON_MODULE' in kwargs.get('undef_macros', []):
#
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/toolchain.py in generate_cxx(module_name, code, specs, optimizations)
#     168             check_specs(ir, specs, renamings, types)
#     169
# --> 170         specs.to_docstrings(docstrings)
#     171
#     172         if isinstance(code, bytes):
#
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/spec.py in to_docstrings(self, docstrings)
#      44     def to_docstrings(self, docstrings):
#      45         for func_name, signatures in self.functions.items():
# ---> 46             sigdocs = [spec_to_string(func_name, sig) for sig in signatures]
#      47             docstrings[func_name] = "Supported prototypes:{}\n{}".format(
#      48                 "".join("\n    - " + sigdoc for sigdoc in sigdocs),
#
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/spec.py in <listcomp>(.0)
#      44     def to_docstrings(self, docstrings):
#      45         for func_name, signatures in self.functions.items():
# ---> 46             sigdocs = [spec_to_string(func_name, sig) for sig in signatures]
#      47             docstrings[func_name] = "Supported prototypes:{}\n{}".format(
#      48                 "".join("\n    - " + sigdoc for sigdoc in sigdocs),
#
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/spec.py in spec_to_string(function_name, spec)
#     397
#     398 def spec_to_string(function_name, spec):
# --> 399     arguments_types = [pytype_to_pretty_type(t) for t in spec]
#     400     return '{}({})'.format(function_name, ', '.join(arguments_types))
#     401
#
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/spec.py in <listcomp>(.0)
#     397
#     398 def spec_to_string(function_name, spec):
# --> 399     arguments_types = [pytype_to_pretty_type(t) for t in spec]
#     400     return '{}({})'.format(function_name, ', '.join(arguments_types))
#     401
#
# /usr/local/lib/python3.6/site-packages/pythran-0.8.3-py3.6.egg/pythran/types/conversion.py in pytype_to_pretty_type(t)
#     118         return t.__name__
#     119     else:
# --> 120         raise NotImplementedError("{0}:{1}".format(type(t), t))
#
# NotImplementedError: <class 'type'>:<class 'pythran.tables.long'>

# %%
# %timeit factorize_naive(3241618756762348687L)
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-55-2a140a4d402f>", line 1, in <module>
#     get_ipython().run_line_magic('timeit', 'factorize_naive(3241618756762348687L)')
#
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2095, in run_line_magic
#     result = fn(*args,**kwargs)
#
#   File "<decorator-gen-61>", line 2, in timeit
#
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/magics/execution.py", line 1041, in timeit
#     ast_stmt = self.shell.compile.ast_parse(transform(stmt))
#
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/compilerop.py", line 99, in ast_parse
#     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
#   File "<unknown>", line 1
#     factorize_naive(3241618756762348687L)
#                                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Cleanup before you leave the room ;-)

# %%
# !rm -rf build dist scrabble.py setup.py scrabble.so # cleanup
