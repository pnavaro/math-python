# %%
import numpy as np

with open('../data/IRMAR-2017-2018.txt') as f:
    data = f.readlines()

org_catalog = ['AGRO', 'INSA', 'R1', 'R2', 'INRIA', 'EXT', 'ENS', 'CNRS']
pos_catalog = ['PR', 'CR', 'DOC', 'MC', 'DR', 'MC-HDR', 'CR-HDR', 'PE',
               'PDOC', 'ADMG', 'TC', 'IR', 'IE', 'AI', 'AGPREP', 'ATER,DOC',
               'ADMG', 'ADM-UFR', 'PRAG', 'CH', 'ADMP', 'CH-HDR', 'ATER', 'LOG']

names, phones, offices, orgs, positions, teams = [], [], [], [], [], []
for m, line in enumerate(data):

    member = line.strip()
    i = member.index('+')
    name = member[:i]
    names.append(name)
    phones.append(member[i:i+17].replace(' ',''))
    remind = member[i+17:].split()
    office = 'NA'
    organization = 'R1'
    team = ['NA']

    # office
    if remind[0].isdigit() or '/' in remind[0]:
        offices.append(remind[0])
        office = remind[0]
        remind.pop(0)
    else:
        offices.append('NA')

    # organization
    if len(remind) > 0 and remind[0] in org_catalog:
        orgs.append(remind[0])
        organization = remind[0]
        remind.pop(0)
    else:
        orgs.append('R1')

    # position
    if len(remind) > 0 and remind[0] in pos_catalog:
        positions.append(remind[0])
        position = remind[0]
        remind.pop(0)
    else:
        position = 'NA'
        positions.append('NA')

    # team
    if len(remind) > 0:
        team = remind[-1].split(',')
        if len(team) == 2:
            teams.append(tuple(team))
        else:
            teams.append(tuple(team+['NA']))
    else:
        teams.append(('ADM','NA'))

irmar = np.zeros(len(data),
dtype={'names': ['name', 'phone', 'office', 'organization', 'position', 'hdr', 'team1', 'team2'],
       'formats': ['U30', 'U17', 'U7', 'U5', 'U6', '?', 'U9', 'U9']})

# %%
irmar['name'] = names
irmar['phone'] = phones
irmar['office'] = offices
irmar['organization'] = orgs

def _hdr(position):
    return any(x in position for x in ['HDR','PR','DR','PE'])
    
irmar['hdr'] = [ _hdr(position) for position in positions]
irmar['position'] = [position.replace('-HDR','') for position in positions]
irmar['team1'] = [team[0] for team in teams]
irmar['team2'] = [team[1] for team in teams]

# %%
import pandas as pd
df = pd.DataFrame(irmar)
df['position'] = df.position.astype('category')
df['team1'] = df.team1.astype('category')
df['team2'] = df.team2.astype('category')
df['organization'] = df.organization.astype('category')
df['hdr'] = df.hdr.astype('bool')

# %%
import json
with open("irmar.json","w") as f:
    json.dump(df.to_json(orient="records"),f)

# %%
df.to_csv("irmar.txt",sep="\t")

# %%
df
# Out:
#                         name         phone office organization position  \
# 0             Alphonse Paul   +33223235223    214           R1      DOC
# 1               Ammari Zied   +33223235811    209           R1       MC
# 2               André Simon   +33223237555    301           R1      DOC
# 3              Angst Jurgen   +33223236519    320           R1       MC
# 4           Bailleul Ismaël   +33223236369    302           R1       MC
# 5                Baker Mark   +33223236028    835           R1       PR
# 6            Balac Stephane   +33223236274    110           R1       MC
# 7                 Bauer Max   +33223236675    734           R1       MC
# 8           Bavard Juliette   +33223236724    331           R1       CR
# 9          Beauchard Karine   +33223236164    235           R1       PR
# 10             Bekka Bachir   +33223235779    307           R1       PR
# 11              Bekka Karim   +33223236180    615           R1       MC
# 12           Belgacem Maher   +33223236670     NA          EXT      DOC
# 13         Bellis Alexandre   +33223236696    634           R1      DOC
# 14          Belmiloudi Aziz   +33223238646     NA         INSA       MC
# 15          Ben Elouefi Rim   +33223236670     NA          EXT      DOC
# 16        Benasseni Jacques   +33299141822     NA           R2       PR
# 17   Bennani-Dosse Mohammed   +33299141796     NA           R2       MC
# 18          Bernier Joachim   +33223237558    214           R1      DOC
# 19         Berthelot Pierre   +33223236043    601           R1       PE
# 20             Bidel Youenn   +33223236647    610           R1      DOC
# 21             Boil Gregory   +33223235740    202           R1      DOC
# 22      Bonthonneau Yannick   +33223237546    211           R1       CR
# 23         Boucher Delphine   +33223236685    612           R1       MC
# 24            Bourqui David   +33223235775    614           R1       MC
# 25          Boutin Benjamin   +33223235883    109           R1       MC
# 26             Brard Margot   +33223236670     NA         AGRO      DOC
# 27   Breton Jean-Christophe   +33223236258    308           R1       PR
# 28              Briane Marc   +33223238539     NA         INSA       PR
# 29             Cadre Benoît   +33299055266     NA          ENS       PR
# ..                       ...           ...    ...          ...      ...
# 214          Rosello Angelo   +33299059311     NA           R1      DOC
# 215        Rouffort Clément   +33223236456  202/1           R1      DOC
# 216        Rousseaux Hélène   +33223236004    131         CNRS       TC
# 217         Rousset Mathias   +33223236670     NA           R1       CR
# 218        Rouviere Laurent   +33299141804     NA           R2       MC
# 219     Roy Marie-Francoise   +33223236020    633           R1       PE
# 220        Schapira Barbara   +33223236000    305           R1       MC
# 221          Schmidt Tobias   +33223234443    604           R1       PR
# 222            Sebag Julien   +33223235871    607           R1       PR
# 223          Seguin Nicolas   +33223237544    109           R1       PR
# 224           Shih Jizhuang   +33223235837    432          ENS     PRAG
# 225              Souto Juan   +33223236509    318           R1       DR
# 226         Tchou Nicoletta   +33223235842    207           R1       MC
# 227    Texier-Picard Rozenn   +33299059333    106           R1       MC
# 228           Thakur Mainak   +33223237550    313           R1     PDOC
# 229            Thom Olivier   +33223236870    634           R1      DOC
# 230         Touzet Frederic   +33223235873    834           R1       MC
# 231          Truquet Lionel   +33223236670     NA           R1       MC
# 232          Tusseau Maxime   +33223235987    206           R1      DOC
# 233             Ulmer Felix   +33223236044    606           R1       PR
# 234            Vauvan Marie   +33223235890  215/1           R1      LOG
# 235       Verger Marie-Aude   +33223236040    033           R1     ADMG
# 236            Virrion Anne   +33223235840    231           R1       MC
# 237      Vu Thi Minh Phuong   +33223236650    621           R1      DOC
# 238             Vu Ngoc San   +33223236039  210/1           R1       PR
# 239           Wiest Bertold   +33223235865    732           R1       MC
# 240               Xie Junyi   +33223237545    309           R1       CR
# 241          Yafaev Dimitri   +33223235832    211           R1       PE
# 242         Zhao Sheng Yuan   +33223237550    313           R1      DOC
# 243            Ziegler Yvan   +33223236624    610           R1   ATER,D
#
#        hdr      team1      team2
# 0    False        EDP         NA
# 1     True        EDP         NA
# 2    False   THEO-ERG         NA
# 3    False  PROC-STOC         NA
# 4     True   THEO-ERG         NA
# 5     True        GAN         NA
# 6    False     ANANUM         NA
# 7    False        GAN         NA
# 8    False        GAN   THEO-ERG
# 9     True     ANANUM         NA
# 10    True   THEO-ERG         NA
# 11   False        G&S         NA
# 12   False     ANANUM         NA
# 13   False        GAN         NA
# 14    True     ANANUM         NA
# 15   False       STAT         NA
# 16    True       STAT         NA
# 17   False       STAT         NA
# 18   False     ANANUM         NA
# 19    True         GA         NA
# 20   False        G&S         NA
# 21   False        EDP         NA
# 22   False        EDP         NA
# 23   False        GAE         NA
# 24    True        G&S         NA
# 25   False     ANANUM         NA
# 26   False       STAT         NA
# 27    True  PROC-STOC         NA
# 28    True        EDP         NA
# 29    True       STAT         NA
# ..     ...        ...        ...
# 214  False     ANANUM  PROC-STOC
# 215  False        EDP         NA
# 216  False        ADM         NA
# 217   True  PROC-STOC         NA
# 218  False       STAT         NA
# 219   True        GAE         NA
# 220   True   THEO-ERG         NA
# 221   True         GA         NA
# 222   True        G&S         NA
# 223   True     ANANUM         NA
# 224   True        ADM         NA
# 225   True        GAN   THEO-ERG
# 226   True        EDP         NA
# 227  False     ANANUM         NA
# 228  False       STAT         NA
# 229  False        GAN         NA
# 230  False        GAN         NA
# 231  False       STAT         NA
# 232  False     ANANUM  PROC-STOC
# 233   True        GAE         NA
# 234  False        ADM         NA
# 235  False        ADM         NA
# 236  False       IREM         NA
# 237  False         GA         NA
# 238   True        EDP         NA
# 239   True        GAN         NA
# 240  False   THEO-ERG         GA
# 241   True        EDP         NA
# 242  False   THEO-ERG         NA
# 243  False        GAE         GA
#
# [244 rows x 8 columns]

# %% [markdown]
# - Combien d'enseignants-chercheurs habilités à diriger des recherches ?

# %%
len(df[df.hdr])
# Out:
# 103

# %% [markdown]
# - Combien d'enseignants-chercheurs de Rennes 2 ?

# %%
len(df[df.organization == 'R2'])
# Out:
# 11

# %%
df.loc[df['name'].str.contains("Guevel")]
# Out:
#                  name         phone office organization position    hdr  \
# 142  Le Guevel Ronan   +33299141800     NA           R2       MC  False
#
#          team1 team2
# 142  PROC-STOC  STAT

# %% [markdown]
# - Liste des MC de l'équipe STATS

# %%
df.loc[df.position == 'MC'].loc[(df.team1 == 'STAT') | (df.team2 == 'STAT')]
# Out:
#                         name         phone office organization position  \
# 17   Bennani-Dosse Mohammed   +33299141796     NA           R2       MC
# 42       Chagneau Pierrette   +33223238528     NA         INSA       MC
# 46        Chauvet Guillaume   +33299053233     NA           R1       MC
# 55   Cornillon Pierre-André   +33299141819     NA           R2       MC
# 83            Emily Mathieu   +33299141807    121           R1       MC
# 85     Etienne Marie-Pierre   +33223485874     NA           R1       MC
# 93            Gares Valérie   +33223238948     NA         INSA       MC
# 96   Giacofci Joyce Madison   +33299141800     NA           R2       MC
# 130    Klutchnikoff Nicolas   +33299141819     NA           R2       MC
# 131          Krell Nathalie   +33223236000    305           R1       MC
# 135            Le Sébastien   +33223485887     NA         AGRO       MC
# 142         Le Guevel Ronan   +33299141800     NA           R2       MC
# 172               Mom Alain   +33299141808     NA           R2       MC
# 218        Rouviere Laurent   +33299141804     NA           R2       MC
# 231          Truquet Lionel   +33223236670     NA           R1       MC
#
#        hdr      team1 team2
# 17   False       STAT    NA
# 42   False       STAT    NA
# 46    True       STAT    NA
# 55   False       STAT    NA
# 83    True       STAT    NA
# 85   False       STAT    NA
# 93   False       STAT    NA
# 96   False       STAT    NA
# 130  False       STAT    NA
# 131  False       STAT    NA
# 135  False       STAT    NA
# 142  False  PROC-STOC  STAT
# 172  False       STAT    NA
# 218  False       STAT    NA
# 231  False       STAT    NA

# %% [markdown]
# - Pourcentage d'EC non doctorants habilités

# %%
df.loc[df.position != 'DOC'].hdr.sum()/df.loc[df.position != 'DOC'].hdr.count()*100
# Out:
# 56.59340659340659

# %%
res = pd.DataFrame()
for position in ['DOC','PR','MC','CR','DR']:
    res[position] = df.loc[df.position == position].groupby('team1').name.count()

# %%
res = res.drop(['INFO','IREM','BIBLI','ADM'])

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,6)

# %%
res.sum().plot.pie(figsize=(8, 8))

# %%
res.sum(axis=1).plot.pie(figsize=(8, 8))

# %% [markdown]
# - Nombre de maitres de conférence

# %%
df['name'].loc[df.position == 'MC'].count()
# Out:
# 62
