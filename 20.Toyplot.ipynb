# %% [markdown]
# Pierre Navaro - [Institut de Recherche Mathématique de Rennes](https://irmar.univ-rennes1.fr) - [CNRS](http://www.cnrs.fr/)

# %%
import toyplot

# %%
import numpy as np
x = np.linspace(0, 10, 100)
y = 1-np.exp(-x)
toyplot.plot(x,y, width=400);
# Out:
# <div class="toyplot" id="tfaa98ff8017d45ae91b20cda5ae8b355" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="400.0px" id="tb50208d250de41a2ab4c6fac8727a7e9" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 400.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tf6bbfa7a412e41cb8be361412d3cd6fd"><clipPath id="t09ee576945bc456c8e1af0123e3f5aa6"><rect height="320.0" width="320.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t09ee576945bc456c8e1af0123e3f5aa6)"><g class="toyplot-mark-Plot" id="t14f5f2a31c2d49009f21b40118bf0a66" style="fill:none"><g class="toyplot-Series"><path d="M 50.0 350.0 L 53.030303030303031 321.17717068
# ...

# %%
import toyplot.locator

canvas = toyplot.Canvas(width=600, height=300)
axes = canvas.cartesian()
axes.label.text = "Condensator charge"
axes.x.label.text = "t"
axes.y.label.text = "Q(t)"
axes.x.ticks.show = True
mark = axes.plot(x, y)
# Out:
# <div class="toyplot" id="t33623e52cfd44fe8975fb195c6b079ae" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t88f6401c42da4e15ba20fb52a451890c" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 300.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t873eb5435f6a4fbd874038bb8cdf3c9a"><clipPath id="tb4e2c6ecca4f4bfd88e7d58745335cd0"><rect height="220.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#tb4e2c6ecca4f4bfd88e7d58745335cd0)"><g class="toyplot-mark-Plot" id="t56ea5938c67940559af8a496dd93eb15" style="fill:none"><g class="toyplot-Series"><path d="M 50.0 250.0 L 55.050505050505052 230.78478045
# ...

# %%
toyplot.fill(x, y,  width=600, height=200);
# Out:
# <div class="toyplot" id="ta8b30a93865f42c3a8ccb5555dd71510" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="200.0px" id="t576ab85dcdca4c32964bc3eb45aff732" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 200.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t197ac00590dd479eaf222b8262ab4021"><clipPath id="t42e253ccee21428db2730e9238b24666"><rect height="120.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t42e253ccee21428db2730e9238b24666)"><g class="toyplot-mark-FillBoundaries" id="tf2dc5b104da747e9bf7732259679e217" style="stroke:none"><polygon points="50.0,150.0 55.050505050505052,150.0 60.1010101010101
# ...

# %%
import numpy
import toyplot
import toyplot.generate
edges = toyplot.generate.barabasi_albert_graph()
toyplot.graph(edges, width=500);

layout = toyplot.layout.FruchtermanReingold()
# Out:
# <div class="toyplot" id="tdffbb1ea7d904fa5ad2eefec42222f57" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="500.0px" id="t15e3d495889e4d69a0f3bb2aaa3ee834" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 500.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tef96734ef4c94670a40b117a4c18fade"><clipPath id="t80423461c0c74b0297bc674ff7bccd81"><rect height="440.0" width="440.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t80423461c0c74b0297bc674ff7bccd81)"><g class="toyplot-mark-Graph" id="tbd4f460caff9442db85383b3c901a1b0"><g class="toyplot-Edges"><path d="M 273.562978187 215.26859522 L 404.678690378 288.642760376" styl
# ...

# %% [markdown]
# Of course, you can assign a $[0, N)$ colormap to the vertices based on their index, or some other variable:

# %%
colormap = toyplot.color.LinearMap(toyplot.color.Palette(["white", "yellow", "red"]))
vstyle = {"stroke":toyplot.color.near_black}

toyplot.graph(edges, layout=layout, vcolor=colormap, vsize=30, vstyle=vstyle, width=500);
# Out:
# <div class="toyplot" id="t2144413df26f4d50b5fc6074acd756b2" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="500.0px" id="td9f733e7a16249ada5832897ce18c3a8" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 500.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tbc37f0fe57154a39ae7fd2b3ac1ba642"><clipPath id="tbf003776c13c47b4988014a1a49284ba"><rect height="440.0" width="440.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#tbf003776c13c47b4988014a1a49284ba)"><g class="toyplot-mark-Graph" id="t6bc559f3096a4334b83b1b3335cbd450"><g class="toyplot-Edges"><path d="M 284.907423542 221.617103673 L 393.334245022 282.294251924" sty
# ...

# %% [markdown]
# Edges can also be rendered with per-edge *head*, *middle*, and *tail* :ref:`markers <markers>`.  For example, if you wish to show the directionality of the edges in a graph, it is customary to add an arrow at the end of each edge:

# %%
toyplot.graph(
    edges,
    layout=layout,
    ecolor="black",
    tmarker=">",
    vcolor=colormap,
    vsize=30,
    vstyle=vstyle,
    width=500,
);
# Out:
# <div class="toyplot" id="tf3c00c233c7e4e61a7e05f685ace4f53" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="500.0px" id="t829cd25138be422f8542775757ffc184" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 500.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tee34e37b0b56475ebe47e443be84acbe"><clipPath id="tc95b46ac79714b7bbdbc95fb9de42c61"><rect height="440.0" width="440.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#tc95b46ac79714b7bbdbc95fb9de42c61)"><g class="toyplot-mark-Graph" id="t94d80a6a351843cfb0afda939fc0f98b"><g class="toyplot-Edges"><path d="M 284.907423542 221.617103673 L 393.334245022 282.294251924" sty
# ...
